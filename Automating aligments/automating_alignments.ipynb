# %%
from rdflib import Graph,Namespace,URIRef,Literal

# %%
g = Graph()
QUDT = Namespace("http://qudt.org/schema/qudt/")
try:
    g.parse("testdata.ttl", format="turtle")
    print(f"Successfully loaded {len(g)} triples.\n")
except Exception as e:
    print(f"Error parsing the file: {e}")
# Out:
# Successfully loaded 50 triples.

# %%
NEW_UNIT = URIRef("http://qudt.org/vocab/unit/K")

for subject in set(g.subjects()):
    unit_value = g.value(subject, QUDT.unit)
    if unit_value is not None:
       print(f"Subject: {subject}")
       print(f"  └── Found target value: {unit_value}")
       g.parse(URIRef(unit_value))
       mult = g.value(unit_value, QUDT.conversionMultiplier)
       off = g.value(unit_value, QUDT.conversionOffset)
       conversion_multiplier = float(mult) if mult is not None else 1.0
       conversion_offset = float(off) if off is not None else 0.0
       print(f"  └── Found conversion multiplier value: {conversion_multiplier}")
       print(f"  └── Found conversion offset value: {conversion_offset}")
       for predicate, obj in g.predicate_objects(subject):
           if (predicate == QUDT.value):
            print(f"     ├── Predicate: {predicate}")
            print(f"     └── Object:    {obj}")
            new_value = (float(obj)+conversion_offset)*conversion_multiplier
            print(f"     ├── converted value: {new_value}")
            print(f"     ├── new unit: {NEW_UNIT}")
            g.set((subject, QUDT.value, Literal(new_value)))
            g.set((subject, QUDT.unit, NEW_UNIT))
# Out:
# Subject: http://example.org/water-monitoring#Val_2026_07_16_0945
#   └── Found target value: http://qudt.org/vocab/unit/DEG_C
#   └── Found conversion multiplier value: 1.0
#   └── Found conversion offset value: 273.15
#      ├── Predicate: http://qudt.org/schema/qudt/value
#      └── Object:    19.1
#      ├── converted value: 292.25
#      ├── new unit: http://qudt.org/vocab/unit/K
# Subject: http://example.org/water-monitoring#Val_2026_07_16_0930
#   └── Found target value: http://qudt.org/vocab/unit/DEG_C
#   └── Found conversion multiplier value: 1.0
#   └── Found conversion offset value: 273.15
#      ├── Predicate: http://qudt.org/schema/qudt/value
#      └── Object:    18.8
#      ├── converted value: 291.95
#      ├── new unit: http://qudt.org/vocab/unit/K
# Subject: http://example.org/water-monitoring#Val_2026_07_16_0900
#   └── Found target value: http://qudt.org/vocab/unit/DEG_C
#   └── Found conversion multiplier value: 1.0
#   └── Found conversion offset value: 273.15
#      ├── Predicate: http://qudt.org/schema/qudt/value
#      └── Object:    18.5
#      ├── converted value: 291.65
#      ├── new unit: http://qudt.org/vocab/unit/K
# Subject: http://example.org/water-monitoring#Val_2026_07_16_1000
#   └── Found target value: http://qudt.org/vocab/unit/DEG_C
#   └── Found conversion multiplier value: 1.0
#   └── Found conversion offset value: 273.15
#      ├── Predicate: http://qudt.org/schema/qudt/value
#      └── Object:    19.4
#      ├── converted value: 292.54999999999995
#      ├── new unit: http://qudt.org/vocab/unit/K
# Subject: http://example.org/water-monitoring#Val_2026_07_16_0915
#   └── Found target value: http://qudt.org/vocab/unit/DEG_C
#   └── Found conversion multiplier value: 1.0
#   └── Found conversion offset value: 273.15
#      ├── Predicate: http://qudt.org/schema/qudt/value
#      └── Object:    18.6
#      ├── converted value: 291.75
#      ├── new unit: http://qudt.org/vocab/unit/K

# %%
print(g.serialize(format="turtle"))
# Out:
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix ex: <http://example.org/water-monitoring#> .
# @prefix qkdv: <http://qudt.org/vocab/dimensionvector/> .
# @prefix quantitykind: <http://qudt.org/vocab/quantitykind/> .
# @prefix qudt: <http://qudt.org/schema/qudt/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix si-unit: <https://si-digital-framework.org/SI/units/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix sosa: <http://www.w3.org/ns/sosa/> .
# @prefix sou: <http://qudt.org/vocab/sou/> .
# @prefix unit: <http://qudt.org/vocab/unit/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ex:Obs_2026_07_16_0900 a sosa:Observation ;
#     rdfs:label "Water Temp Observation - 09:00" ;
#     sosa:hasFeatureOfInterest ex:ReservoirAlpha ;
#     sosa:hasResult ex:Val_2026_07_16_0900 ;
#     sosa:madeBySensor ex:WaterTempSensor_ModelXYZ_123 ;
#     sosa:observedProperty ex:ReservoirAlphaWaterTemperature ;
#     sosa:resultTime "2026-07-16T09:00:00+00:00"^^xsd:dateTime .
#
# ex:Obs_2026_07_16_0915 a sosa:Observation ;
#     rdfs:label "Water Temp Observation - 09:15" ;
#     sosa:hasFeatureOfInterest ex:ReservoirAlpha ;
#     sosa:hasResult ex:Val_2026_07_16_0915 ;
#     sosa:madeBySensor ex:WaterTempSensor_ModelXYZ_123 ;
#     sosa:observedProperty ex:ReservoirAlphaWaterTemperature ;
#     sosa:resultTime "2026-07-16T09:15:00+00:00"^^xsd:dateTime .
#
# ex:Obs_2026_07_16_0930 a sosa:Observation ;
#     rdfs:label "Water Temp Observation - 09:30" ;
#     sosa:hasFeatureOfInterest ex:ReservoirAlpha ;
#     sosa:hasResult ex:Val_2026_07_16_0930 ;
#     sosa:madeBySensor ex:WaterTempSensor_ModelXYZ_123 ;
#     sosa:observedProperty ex:ReservoirAlphaWaterTemperature ;
#     sosa:resultTime "2026-07-16T09:30:00+00:00"^^xsd:dateTime .
#
# ex:Obs_2026_07_16_0945 a sosa:Observation ;
#     rdfs:label "Water Temp Observation - 09:45" ;
#     sosa:hasFeatureOfInterest ex:ReservoirAlpha ;
#     sosa:hasResult ex:Val_2026_07_16_0945 ;
#     sosa:madeBySensor ex:WaterTempSensor_ModelXYZ_123 ;
#     sosa:observedProperty ex:ReservoirAlphaWaterTemperature ;
#     sosa:resultTime "2026-07-16T09:45:00+00:00"^^xsd:dateTime .
#
# ex:Obs_2026_07_16_1000 a sosa:Observation ;
#     rdfs:label "Water Temp Observation - 10:00" ;
#     sosa:hasFeatureOfInterest ex:ReservoirAlpha ;
#     sosa:hasResult ex:Val_2026_07_16_1000 ;
#     sosa:madeBySensor ex:WaterTempSensor_ModelXYZ_123 ;
#     sosa:observedProperty ex:ReservoirAlphaWaterTemperature ;
#     sosa:resultTime "2026-07-16T10:00:00+00:00"^^xsd:dateTime .
#
# unit:DEG_C a qudt:DerivedUnit,
#         qudt:Unit ;
#     rdfs:label "Degree Celsius",
#         "درجة مئوية"@ar,
#         "Градус Целзий"@bg,
#         "Stupně Celsia"@cs,
#         "Grad Celsius"@de,
#         "Βαθμός Κελσίου"@el,
#         "Degree Celsius"@en,
#         "Grado Celsius"@es,
#         "درجه سانتی گراد/سلسیوس"@fa,
#         "Degré Celsius"@fr,
#         "צלזיוס"@he,
#         "सेल्सियस"@hi,
#         "Celsius-fok"@hu,
#         "Grado Celsius"@it,
#         "セルシウス度"@ja,
#         "Gradus Celsii"@la,
#         "Darjah Celsius"@ms,
#         "Stopień Celsjusza"@pl,
#         "Grau Celsius"@pt,
#         "Grad Celsius"@ro,
#         "Градус Цельсия"@ru,
#         "Stopinja Celzija"@sl,
#         "Celsius"@tr,
#         "摄氏度"@zh ;
#     dcterms:description """
#   The unit $\\textit{Celsius}$, also known as centigrade, is a scale and unit of measurement for temperature.
#   It can refer to a specific temperature on the Celsius scale as well as a unit to indicate a temperature interval,
#   a difference between two temperatures or an uncertainty.
#   This definition fixes the magnitude of both the degree Celsius and the kelvin as precisely 1 part
#   in 273.16 (approximately 0.00366) of the difference between absolute zero and the triple point of water.
#   Thus, it sets the magnitude of one degree Celsius and that of one kelvin as exactly the same.
#   Additionally, it establishes the difference between the two scales' null points as being precisely $273.15^{\\circ}\\text{C}$.
#   """^^qudt:LatexString ;
#     qudt:applicableSystem sou:CGS,
#         sou:SI ;
#     qudt:conversionMultiplier 1.0 ;
#     qudt:conversionMultiplierSN 1e+00 ;
#     qudt:conversionOffset 273.15 ;
#     qudt:conversionOffsetSN 2.7315e+02 ;
#     qudt:dbpediaMatch "http://dbpedia.org/resource/Celsius"^^xsd:anyURI ;
#     qudt:expression "$degC$"^^qudt:LatexString ;
#     qudt:guidance "<p>See NIST section <a href=\"http://physics.nist.gov/Pubs/SP811/sec04.html#4.2.1.1\">SP811 section 4.2.1.1</a></p>"^^rdf:HTML,
#         "<p>See NIST section <a href=\"http://physics.nist.gov/Pubs/SP811/sec06.html#6.2.8\">SP811 section 6.2.8</a></p>"^^rdf:HTML ;
#     qudt:hasDimensionVector qkdv:A0E0L0I0M0H1T0D0 ;
#     qudt:hasQuantityKind quantitykind:BoilingPoint,
#         quantitykind:FlashPoint,
#         quantitykind:MeltingPoint,
#         quantitykind:Temperature ;
#     qudt:iec61360Code "0112/2///62720#UAA033" ;
#     qudt:informativeReference "https://cdd.iec.ch/cdd/iec62720/iec62720.nsf/Units/0112-2---62720%23UAA033"^^xsd:anyURI,
#         "https://en.wikipedia.org/wiki/Celsius?oldid=494152178"^^xsd:anyURI ;
#     qudt:latexDefinition "$\\,^{\\circ}{C}$"^^qudt:LatexString ;
#     qudt:omUnit <http://www.ontology-of-units-of-measure.org/resource/om-2/degreeCelsius> ;
#     qudt:scalingOf unit:K ;
#     qudt:siExactMatch si-unit:degreeCelsius ;
#     qudt:symbol "°C" ;
#     qudt:ucumCode "Cel"^^qudt:UCUMcs ;
#     qudt:udunitsCode "°C",
#         "℃" ;
#     qudt:uneceCommonCode "CEL" ;
#     qudt:unitForQuantityKind quantitykind:BoilingPoint,
#         quantitykind:FlashPoint,
#         quantitykind:MeltingPoint,
#         quantitykind:Temperature ;
#     qudt:wikidataMatch <http://www.wikidata.org/entity/Q25267> ;
#     rdfs:isDefinedBy <http://qudt.org/3.4.0/vocab/unit> ;
#     skos:altLabel "degree-centigrade" .
#
# ex:Val_2026_07_16_0900 a qudt:QuantityValue ;
#     qudt:unit unit:K ;
#     qudt:value 2.9165e+02 .
#
# ex:Val_2026_07_16_0915 a qudt:QuantityValue ;
#     qudt:unit unit:K ;
#     qudt:value 2.9175e+02 .
#
# ex:Val_2026_07_16_0930 a qudt:QuantityValue ;
#     qudt:unit unit:K ;
#     qudt:value 2.9195e+02 .
#
# ex:Val_2026_07_16_0945 a qudt:QuantityValue ;
#     qudt:unit unit:K ;
#     qudt:value 2.9225e+02 .
#
# ex:Val_2026_07_16_1000 a qudt:QuantityValue ;
#     qudt:unit unit:K ;
#     qudt:value 2.9255e+02 .
