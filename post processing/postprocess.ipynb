# %%
from rdflib import Graph, Namespace

# %%
g = Graph()

# %%
file_path = "../data/timeseries.ttl"
g.parse(file_path, format="turtle")
print(f"Graph loaded with {len(g)} triples.\n")
# Out:
# Graph loaded with 6759990 triples.
