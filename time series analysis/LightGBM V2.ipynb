# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import requests
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
VIRTUOSO_URL = "http://localhost:8890/sparql"
GRAPH_URI    = "http://example.com/Gent-Terneuzen"
USERNAME     = "dba"
PASSWORD     = "dba"
AUTH         = (USERNAME, PASSWORD)

# %%
params  = {'graph': GRAPH_URI}
headers = {'Accept': 'text/turtle'}

# %% [markdown]
# # Identifying unique sensors

# %%
sensor_set = set()

sensor_query = f"""
    PREFIX sosa: <http://www.w3.org/ns/sosa/>
    SELECT DISTINCT ?sensor
    WHERE {{
        GRAPH <{GRAPH_URI}> {{
            # ?obs a sosa:Observation ;
                 sosa:madeBySensor ?sensor .
        }}
    }}
    """
res = requests.get(VIRTUOSO_URL, params={'query': sensor_query, 'format': 'application/sparql-results+json'})
if res.status_code != 200:
    print(f"Error: {res.status_code}")
    print("Response:", res.text)
else:
    print("Unique sensors identified successfully!")

data     = res.json()
bindings = data['results']['bindings']
for row in bindings:
    sensor_set.add(row['sensor']['value'])

print(f"Added {len(sensor_set)} unique sensors to the set.")
print("Sensors:", sensor_set)
# Out:
# Unique sensors identified successfully!
# Added 4 unique sensors to the set.
# Sensors: {'http://example.com/waterinfo/289429042', 'http://example.com/waterinfo/289423042', 'http://example.com/waterinfo/289435042', 'http://example.com/waterinfo/289441042'}

# %% [markdown]
# # Reframe the data

# %%
final_df = pd.DataFrame()
print("Fetching and pivoting sensor data...")

for sensor_uri in sensor_set:
    column_name = sensor_uri.split('/')[-1]
    query = f"""
        PREFIX sosa: <http://www.w3.org/ns/sosa/>
        PREFIX ex: <http://example.com/attributes/>
        SELECT ?time ?value ?unixtime
        WHERE {{
            GRAPH <{GRAPH_URI}> {{
                # ?obs a sosa:Observation ;
                    sosa:resultTime ?time ;
                    sosa:hasSimpleResult ?value ;
                    ex:unixTimestamp ?unixtime ;
                    sosa:madeBySensor <{sensor_uri}> .
            }}
        }}
    """
    res = requests.get(VIRTUOSO_URL, params={'query': query, 'format': 'application/sparql-results+json'})
    if res.status_code == 200:
        bindings = res.json()['results']['bindings']
        temp_data = [
            {'time': row['time']['value'], column_name: float(row['value']['value']),
             'unixtime': int(row['unixtime']['value'])}
            for row in bindings
        ]
        temp_df = pd.DataFrame(temp_data)
        if not temp_df.empty:
            temp_df['time'] = pd.to_datetime(temp_df['time'])
            if final_df.empty:
                final_df = temp_df
            else:
                final_df = pd.merge(final_df, temp_df, on=['time', 'unixtime'], how='outer')
            print(f"Added column for sensor: {column_name}")

final_df = final_df.sort_values('time').set_index('time')
print("Finished!")
print(final_df.head())
# Out:
# Fetching and pivoting sensor data...
# Added column for sensor: 289429042
# Added column for sensor: 289423042
# Added column for sensor: 289435042
# Added column for sensor: 289441042
# Finished!
#                            289429042    unixtime  289423042  289435042  \
# time
# 2021-03-03 23:15:00+00:00    1605.77  1614813300        NaN    3606.54
# 2021-03-03 23:30:00+00:00        NaN  1614814200        NaN        NaN
# 2021-03-03 23:45:00+00:00    1602.34  1614815100     902.27    3556.45
# 2021-03-04 00:00:00+00:00    1611.26  1614816000        NaN        NaN
# 2021-03-04 00:15:00+00:00    1614.24  1614816900     901.96        NaN
#
#                            289441042
# time
# 2021-03-03 23:15:00+00:00    4797.72
# 2021-03-03 23:30:00+00:00    4717.80
# 2021-03-03 23:45:00+00:00    4745.36
# 2021-03-04 00:00:00+00:00        NaN
# 2021-03-04 00:15:00+00:00        NaN

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(12, 10), sharex=True)

sensors = ['289435042', '289423042', '289429042', '289441042']
colors  = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

for i, sensor in enumerate(sensors):
    ax = axes[i]
    ax.plot(final_df.index, final_df[sensor], label=f"Sensor {sensor}", color=colors[i])
    ax.set_ylabel("Value")
    ax.legend(loc='upper right')
    ax.grid(True, alpha=0.3)

plt.suptitle("Sensor Data Analysis", fontsize=16)
plt.xlabel("Time")
plt.xticks(rotation=45)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
data = final_df.copy()
target_sensor = '289441042'

# 1. Time-based features (Seasonality)
data['hour'] = data.index.hour
data['day_of_week'] = data.index.dayofweek
data['month'] = data.index.month


# 2. Lag features for the TARGET (Sensor 4)
    # We look back 15m, 1h, and 24h
for lag in [1, 4, 96,672, 2880]:
    data[f'{target_sensor}_lag_{lag}'] = data[target_sensor].shift(lag)

# 3. Spatial Lag features for NEIGHBORS (Sensors 1, 2, 3)
# These provide "upstream" context
neighbors = [c for c in final_df.columns if c != target_sensor]

for s in neighbors:
        data[f'{s}_lag_1'] = data[s].shift(1)  # What happened 15 mins ago upstream?
        data[f'{s}_lag_4'] = data[s].shift(4)  # What happened 1 hour ago upstream?
        data[f'{s}_lag_672']  = data[s].shift(672)   # 1 week ago upstream
        data[f'{s}_lag_2880'] = data[s].shift(2880)
        data[f'{s}_roc_1']  = data[s].diff(1)   # upstream rate of change
        data[f'{s}_roc_4']  = data[s].diff(4)   # upstream hourly change
        data[f'{s}_roc_672']  = data[s].diff(672)   # upstream weekly change
        data[f'{s}_roc_2880'] = data[s].diff(2880)  # upstream monthly change

# 4. Rolling statistics (Trend)
data['rolling_mean_6h'] = data[target_sensor].shift(1).rolling(window=24).mean()

# In Cell 9, after rolling_mean_6h:

# Rate of change (is the signal rising or falling fast?)
data['roc_1']  = data[target_sensor].diff(1)   # 15-min change
data['roc_4']  = data[target_sensor].diff(4)   # 1-hour change
data['roc_96'] = data[target_sensor].diff(96)  # 24-hour change

# Volatility (is the signal stable or jumping around?)
data['rolling_std_6h']  = data[target_sensor].shift(1).rolling(window=24).std()
data['rolling_std_24h'] = data[target_sensor].shift(1).rolling(window=96).std()

# Rolling min/max (captures the range of recent behaviour)
data['rolling_max_24h'] = data[target_sensor].shift(1).rolling(window=96).max()
data['rolling_min_24h'] = data[target_sensor].shift(1).rolling(window=96).min()


data.dropna(inplace=True)
df_featured = data.copy()
print(f"df_featured shape: {df_featured.shape}")
print(f"Date range: {df_featured.index.min()} → {df_featured.index.max()}")
# Out:
# df_featured shape: (75402, 53)
# Date range: 2023-02-06 14:00:00+00:00 → 2025-10-07 07:30:00+00:00

# %% [markdown]
# # Data preparation

# %%
# Split based on your specific dates
train_data = df_featured[:'2025-07-31'] # all data up to July 2025
test_data = df_featured['2025-07-01':'2025-07-30'] # ground truth month



X_train = train_data.drop(columns=sensors)  # Drop original sensor columns
y_train = train_data[target_sensor]

X_test = test_data.drop(columns=sensors)
y_test = test_data[target_sensor]

# Does the data contain high conductivity events? 
print("Train conductivity range:", y_train.min(), "→", y_train.max())
print("Test  conductivity range:", y_test.min(),  "→", y_test.max())
# Out:
# Train conductivity range: 226.79 → 16851.66
# Test  conductivity range: 6074.92 → 7693.67

# %%
# Sanity check
# #print("Training data shape:", X_train.shape)
# print("Testing data shape:", X_test.shape)
# #print(X_train.head())
# print(X_test.head())

# %% [markdown]
# # Actual training

# %%
model = lgb.LGBMRegressor(
    n_estimators=5000,      # Increased: More trees for better learning
    learning_rate=0.01,     # Decreased: Slower, more precise learning
    num_leaves=128,         # Increased: Allows for more complex patterns
    max_depth=12,           # Limited: Prevents the trees from growing too deep
    min_data_in_leaf=50,   # Regularization: Prevents overfitting to noise (lower = more sensitive)
    feature_fraction=0.8,   # Generalization: Don't rely on all sensors at once
    n_jobs=-1,
    subsample=0.8,          # ADD: row subsampling for better generalisation
    reg_alpha=0.1,          # ADD: L1 regularisation
    reg_lambda=0.1,         # ADD: L2 regularisation
)

# Use early stopping to find the perfect n_estimators automatically
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric='rmse',
    callbacks=[lgb.early_stopping(stopping_rounds=100)] 
)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007059 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10783
# [LightGBM] [Info] Number of data points in the train set: 69041, number of used features: 47
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Start training from score 6231.913078
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [4995]	valid_0's rmse: 9.54369	valid_0's l2: 91.082
# LGBMRegressor(feature_fraction=0.8, learning_rate=0.01, max_depth=12,
#               min_data_in_leaf=50, n_estimators=5000, n_jobs=-1, num_leaves=128,
#               reg_alpha=0.1, reg_lambda=0.1, subsample=0.8)

# %% [markdown]
# # Forecast and Compare

# %%
forecast = model.predict(X_test)

mae = mean_absolute_error(y_test, forecast)
print(f"September 2025 Forecast MAE: {mae:.4f} units of conductivity")
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# September 2025 Forecast MAE: 7.2587 units of conductivity

# %% [markdown]
# # Bias check

# %%
error = y_test - forecast
print(f"Mean Error (Bias): {error.mean()}")

# positive bias means we are underpredicting on average, negative bias means we are overpredicting on average.
# Out:
# Mean Error (Bias): 0.06415687846687539

# %% [markdown]
# # Visualizing truth vs prediction

# %%
# 1. Create a DataFrame for easy plotting
results = pd.DataFrame({
    'Actual': y_test,
    'Forecast': forecast
}, index=y_test.index)

# 2. Plotting a 7-day window to see the detail
plt.figure(figsize=(15, 7))
plt.plot(results['Actual'].iloc[:2688], label='Ground Truth (Actual)', color='blue', alpha=0.7)
# 672 rows = 7 days * 24 hours * 4 readings/hour
plt.plot(results['Forecast'].iloc[:2688], label='LightGBM Forecast', color='red', linestyle='--')

plt.title('Conductivity Forecast vs Ground Truth (Month of September 2025)')
plt.xlabel('Date')
plt.ylabel('Conductivity (μS/cm)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## The model is really good in predicting a week in the future. Any more than that and it falls of quite quickly

# %% [markdown]
# # XGBoost

# %%
# 1. Convert your data into XGBoost's optimized format (DMatrix)
# Note: You use the same X_train, y_train we created for LightGBM
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
params = {
    'objective': 'reg:squarederror', # We are predicting a number (conductivity)
    'max_depth': 6,                 # Depth of trees
    'eta': 0.01,                    # Learning rate (same as 'learning_rate')
    'subsample': 0.8,               # Use 80% of data to grow each tree (prevents overfitting)
    'colsample_bytree': 0.8,        # Use 80% of sensors for each tree
    'eval_metric': 'mae'
}

# We use 'evallist' to watch the error in real-time
evallist = [(dtrain, 'train'), (dtest, 'eval')]
num_round = 2000

bst = xgb.train(params, dtrain, num_round, evallist, early_stopping_rounds=50)

# 4. Forecast 
predictions_xgb = bst.predict(dtest)
# Out:
# [0]	train-mae:2711.47670	eval-mae:737.40756
# [1]	train-mae:2684.41138	eval-mae:729.97750
# [2]	train-mae:2657.61953	eval-mae:722.61716
# [3]	train-mae:2631.10090	eval-mae:715.33575
# [4]	train-mae:2604.84195	eval-mae:708.06743
# [5]	train-mae:2578.85027	eval-mae:700.91154
# [6]	train-mae:2553.11468	eval-mae:693.80918
# [7]	train-mae:2527.63710	eval-mae:686.80386
# [8]	train-mae:2502.41575	eval-mae:679.87559
# [9]	train-mae:2477.45571	eval-mae:673.13426
# [10]	train-mae:2452.74014	eval-mae:666.32053
# C:\Users\AYMANS\AppData\Roaming\Python\Python313\site-packages\xgboost\core.py:748: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [11]	train-mae:2428.27121	eval-mae:659.61158
# [12]	train-mae:2404.04112	eval-mae:652.95517
# [13]	train-mae:2380.05948	eval-mae:646.37796
# [14]	train-mae:2356.31727	eval-mae:639.84808
# [15]	train-mae:2332.80790	eval-mae:633.44714
# [16]	train-mae:2309.53594	eval-mae:627.15559
# [17]	train-mae:2286.49736	eval-mae:620.81660
# [18]	train-mae:2263.68191	eval-mae:614.54357
# [19]	train-mae:2241.10160	eval-mae:608.31612
# [20]	train-mae:2218.80161	eval-mae:602.26735
# [21]	train-mae:2196.66483	eval-mae:596.18148
# [22]	train-mae:2174.75136	eval-mae:590.26392
# [23]	train-mae:2153.05962	eval-mae:584.28855
# [24]	train-mae:2131.58850	eval-mae:578.38205
# [25]	train-mae:2110.42084	eval-mae:572.85420
# [26]	train-mae:2089.37386	eval-mae:567.06439
# [27]	train-mae:2068.53135	eval-mae:561.33122
# [28]	train-mae:2047.90011	eval-mae:555.64633
# [29]	train-mae:2027.48661	eval-mae:550.02850
# [30]	train-mae:2007.31356	eval-mae:544.50837
# [31]	train-mae:1987.29643	eval-mae:539.01464
# [32]	train-mae:1967.48068	eval-mae:533.58862
# [33]	train-mae:1947.86322	eval-mae:528.25205
# [34]	train-mae:1928.45020	eval-mae:522.98998
# [35]	train-mae:1909.22143	eval-mae:517.73603
# [36]	train-mae:1890.18867	eval-mae:512.61477
# [37]	train-mae:1871.34557	eval-mae:507.42468
# [38]	train-mae:1852.69573	eval-mae:502.36373
# [39]	train-mae:1834.23060	eval-mae:497.37827
# [40]	train-mae:1815.95134	eval-mae:492.42892
# [41]	train-mae:1797.84426	eval-mae:487.46278
# [42]	train-mae:1779.92914	eval-mae:482.61022
# [43]	train-mae:1762.19043	eval-mae:477.80218
# [44]	train-mae:1744.62102	eval-mae:472.98205
# [281]	train-mae:165.55256	eval-mae:46.52187
# [282]	train-mae:163.95207	eval-mae:46.17504
# [283]	train-mae:162.35884	eval-mae:45.75136
# [284]	train-mae:160.77622	eval-mae:45.34366
# [285]	train-mae:159.20616	eval-mae:44.96019
# [286]	train-mae:157.66057	eval-mae:44.58307
# [287]	train-mae:156.12402	eval-mae:44.19261
# [288]	train-mae:154.60935	eval-mae:43.80518
# [289]	train-mae:153.11990	eval-mae:43.44671
# [290]	train-mae:151.62784	eval-mae:43.05187
# [291]	train-mae:150.15239	eval-mae:42.70472
# [292]	train-mae:148.68705	eval-mae:42.31930
# [293]	train-mae:147.23651	eval-mae:41.92458
# [294]	train-mae:145.80294	eval-mae:41.53944
# [295]	train-mae:144.39108	eval-mae:41.16514
# [296]	train-mae:142.99657	eval-mae:40.83178
# [297]	train-mae:141.62024	eval-mae:40.48261
# [298]	train-mae:140.24325	eval-mae:40.11812
# [299]	train-mae:138.87829	eval-mae:39.76591
# [300]	train-mae:137.52672	eval-mae:39.40229
# [301]	train-mae:136.19232	eval-mae:39.06425
# [302]	train-mae:134.87651	eval-mae:38.69511
# [303]	train-mae:133.56619	eval-mae:38.40025
# [304]	train-mae:132.26991	eval-mae:38.06842
# [305]	train-mae:130.98616	eval-mae:37.74721
# [306]	train-mae:129.71745	eval-mae:37.45681
# [307]	train-mae:128.46007	eval-mae:37.16196
# [308]	train-mae:127.21657	eval-mae:36.85792
# [309]	train-mae:125.99212	eval-mae:36.56449
# [310]	train-mae:124.76923	eval-mae:36.24738
# [311]	train-mae:123.56288	eval-mae:35.94735
# [312]	train-mae:122.36595	eval-mae:35.66079
# [313]	train-mae:121.18094	eval-mae:35.36510
# [314]	train-mae:120.00832	eval-mae:35.06809
# [315]	train-mae:118.85054	eval-mae:34.75062
# [316]	train-mae:117.70793	eval-mae:34.48172
# [317]	train-mae:116.56656	eval-mae:34.17885
# [318]	train-mae:115.44628	eval-mae:33.88165
# [319]	train-mae:114.35022	eval-mae:33.66692
# [320]	train-mae:113.24671	eval-mae:33.36273
# [321]	train-mae:112.15538	eval-mae:33.11790
# [322]	train-mae:111.07115	eval-mae:32.82910
# [323]	train-mae:110.00077	eval-mae:32.57945
# [324]	train-mae:108.93763	eval-mae:32.28901
# [325]	train-mae:107.88814	eval-mae:32.02443
# [326]	train-mae:106.85705	eval-mae:31.78330
# [327]	train-mae:105.83256	eval-mae:31.51760
# [328]	train-mae:104.81247	eval-mae:31.24593
# [329]	train-mae:103.80836	eval-mae:31.02850
# [330]	train-mae:102.80994	eval-mae:30.80267
# [331]	train-mae:101.82013	eval-mae:30.53506
# [332]	train-mae:100.84841	eval-mae:30.33207
# [333]	train-mae:99.87890	eval-mae:30.10825
# [334]	train-mae:98.92940	eval-mae:29.90023
# [335]	train-mae:97.97964	eval-mae:29.67374
# [336]	train-mae:97.05509	eval-mae:29.50848
# [337]	train-mae:96.13544	eval-mae:29.31674
# [338]	train-mae:95.21415	eval-mae:29.08714
# [339]	train-mae:94.31281	eval-mae:28.87416
# [400]	train-mae:53.15876	eval-mae:18.73885
# [401]	train-mae:52.67787	eval-mae:18.64240
# [402]	train-mae:52.21151	eval-mae:18.54735
# [403]	train-mae:51.73865	eval-mae:18.43311
# [404]	train-mae:51.27000	eval-mae:18.33195
# [405]	train-mae:50.80604	eval-mae:18.20975
# [406]	train-mae:50.34762	eval-mae:18.09864
# [407]	train-mae:49.89330	eval-mae:17.99791
# [408]	train-mae:49.44360	eval-mae:17.88144
# [409]	train-mae:48.99863	eval-mae:17.76161
# [410]	train-mae:48.56213	eval-mae:17.67867
# [411]	train-mae:48.12849	eval-mae:17.57308
# [412]	train-mae:47.69906	eval-mae:17.46466
# [413]	train-mae:47.27900	eval-mae:17.35833
# [414]	train-mae:46.86058	eval-mae:17.25818
# [415]	train-mae:46.44532	eval-mae:17.16528
# [416]	train-mae:46.03390	eval-mae:17.06625
# [417]	train-mae:45.62709	eval-mae:16.96280
# [418]	train-mae:45.22495	eval-mae:16.86143
# [419]	train-mae:44.82623	eval-mae:16.76212
# [420]	train-mae:44.43613	eval-mae:16.69263
# [421]	train-mae:44.04718	eval-mae:16.58699
# [422]	train-mae:43.66684	eval-mae:16.51471
# [423]	train-mae:43.28983	eval-mae:16.43412
# [424]	train-mae:42.91473	eval-mae:16.34195
# [425]	train-mae:42.54612	eval-mae:16.26737
# [426]	train-mae:42.18220	eval-mae:16.17297
# [427]	train-mae:41.81720	eval-mae:16.08944
# [428]	train-mae:41.45804	eval-mae:16.00356
# [429]	train-mae:41.10046	eval-mae:15.92205
# [430]	train-mae:40.74984	eval-mae:15.84187
# [431]	train-mae:40.40337	eval-mae:15.75912
# [432]	train-mae:40.06120	eval-mae:15.68933
# [433]	train-mae:39.71719	eval-mae:15.61048
# [434]	train-mae:39.38057	eval-mae:15.52457
# [435]	train-mae:39.04744	eval-mae:15.44804
# [436]	train-mae:38.72214	eval-mae:15.37383
# [437]	train-mae:38.39716	eval-mae:15.29521
# [438]	train-mae:38.07928	eval-mae:15.20652
# [439]	train-mae:37.76178	eval-mae:15.13421
# [440]	train-mae:37.44509	eval-mae:15.05809
# [441]	train-mae:37.13449	eval-mae:14.98456
# [442]	train-mae:36.83978	eval-mae:14.95051
# [443]	train-mae:36.53485	eval-mae:14.87985
# [444]	train-mae:36.23305	eval-mae:14.80838
# [445]	train-mae:35.93730	eval-mae:14.73826
# [446]	train-mae:35.64583	eval-mae:14.67694
# [447]	train-mae:35.35691	eval-mae:14.60055
# [448]	train-mae:35.07189	eval-mae:14.54390
# [449]	train-mae:34.78741	eval-mae:14.46517
# [450]	train-mae:34.51012	eval-mae:14.41107
# [451]	train-mae:34.23303	eval-mae:14.34360
# [452]	train-mae:33.96151	eval-mae:14.29476
# [453]	train-mae:33.69008	eval-mae:14.22800
# [454]	train-mae:33.42142	eval-mae:14.16295
# [455]	train-mae:33.15409	eval-mae:14.09361
# [456]	train-mae:32.89205	eval-mae:14.03056
# [457]	train-mae:32.63685	eval-mae:13.98996
# [458]	train-mae:32.38468	eval-mae:13.91958
# [459]	train-mae:32.13314	eval-mae:13.85370
# [460]	train-mae:31.88215	eval-mae:13.80092
# [461]	train-mae:31.63892	eval-mae:13.75279
# [462]	train-mae:31.39477	eval-mae:13.69171
# [463]	train-mae:31.15564	eval-mae:13.63674
# [464]	train-mae:30.92141	eval-mae:13.58355
# [465]	train-mae:30.68766	eval-mae:13.52771
# [466]	train-mae:30.45637	eval-mae:13.46756
# [467]	train-mae:30.22694	eval-mae:13.41022
# [468]	train-mae:30.00173	eval-mae:13.36014
# [469]	train-mae:29.77885	eval-mae:13.30485
# [470]	train-mae:29.55958	eval-mae:13.24097
# [471]	train-mae:29.34070	eval-mae:13.18856
# [472]	train-mae:29.12406	eval-mae:13.13241
# [473]	train-mae:28.91022	eval-mae:13.07571
# [474]	train-mae:28.70933	eval-mae:13.04195
# [475]	train-mae:28.50201	eval-mae:12.98645
# [476]	train-mae:28.29769	eval-mae:12.93202
# [477]	train-mae:28.09827	eval-mae:12.89036
# [478]	train-mae:27.89828	eval-mae:12.85498
# [479]	train-mae:27.70230	eval-mae:12.80782
# [480]	train-mae:27.51051	eval-mae:12.76665
# [481]	train-mae:27.32110	eval-mae:12.72356
# [482]	train-mae:27.12877	eval-mae:12.67708
# [483]	train-mae:26.94151	eval-mae:12.62643
# [484]	train-mae:26.75519	eval-mae:12.58115
# [485]	train-mae:26.57234	eval-mae:12.53201
# [486]	train-mae:26.39438	eval-mae:12.49411
# [487]	train-mae:26.21645	eval-mae:12.44443
# [488]	train-mae:26.05016	eval-mae:12.42981
# [489]	train-mae:25.87406	eval-mae:12.38377
# [490]	train-mae:25.70526	eval-mae:12.35254
# [491]	train-mae:25.53415	eval-mae:12.30669
# [492]	train-mae:25.36444	eval-mae:12.26495
# [493]	train-mae:25.19913	eval-mae:12.22566
# [494]	train-mae:25.03517	eval-mae:12.17995
# [495]	train-mae:24.87593	eval-mae:12.13899
# [496]	train-mae:24.71939	eval-mae:12.09902
# [497]	train-mae:24.56566	eval-mae:12.06322
# [498]	train-mae:24.41078	eval-mae:12.01930
# [499]	train-mae:24.25856	eval-mae:11.97615
# [500]	train-mae:24.10688	eval-mae:11.93957
# [501]	train-mae:23.95868	eval-mae:11.90358
# [502]	train-mae:23.81366	eval-mae:11.86971
# [503]	train-mae:23.66723	eval-mae:11.83192
# [504]	train-mae:23.52489	eval-mae:11.79695
# [505]	train-mae:23.38666	eval-mae:11.76796
# [506]	train-mae:23.24778	eval-mae:11.72945
# [507]	train-mae:23.11120	eval-mae:11.69201
# [508]	train-mae:22.98668	eval-mae:11.67936
# [509]	train-mae:22.85471	eval-mae:11.64325
# [510]	train-mae:22.72353	eval-mae:11.60780
# [511]	train-mae:22.59370	eval-mae:11.57319
# [512]	train-mae:22.46487	eval-mae:11.54239
# [513]	train-mae:22.34186	eval-mae:11.51530
# [514]	train-mae:22.21662	eval-mae:11.47226
# [515]	train-mae:22.09415	eval-mae:11.42973
# [516]	train-mae:21.97587	eval-mae:11.39991
# [517]	train-mae:21.85783	eval-mae:11.37260
# [518]	train-mae:21.73903	eval-mae:11.34346
# [519]	train-mae:21.62452	eval-mae:11.30821
# [520]	train-mae:21.51120	eval-mae:11.27511
# [521]	train-mae:21.39856	eval-mae:11.24504
# [522]	train-mae:21.28768	eval-mae:11.21942
# [523]	train-mae:21.17789	eval-mae:11.19016
# [524]	train-mae:21.06852	eval-mae:11.16141
# [525]	train-mae:20.96265	eval-mae:11.13356
# [526]	train-mae:20.85796	eval-mae:11.10437
# [527]	train-mae:20.75366	eval-mae:11.07838
# [528]	train-mae:20.65250	eval-mae:11.05283
# [529]	train-mae:20.55324	eval-mae:11.03011
# [530]	train-mae:20.45376	eval-mae:11.00457
# [531]	train-mae:20.35557	eval-mae:10.97253
# [532]	train-mae:20.25897	eval-mae:10.95212
# [533]	train-mae:20.16360	eval-mae:10.92664
# [534]	train-mae:20.07050	eval-mae:10.90412
# [535]	train-mae:19.97699	eval-mae:10.87594
# [536]	train-mae:19.88483	eval-mae:10.84940
# [537]	train-mae:19.79700	eval-mae:10.82187
# [538]	train-mae:19.70959	eval-mae:10.80133
# [539]	train-mae:19.62160	eval-mae:10.77745
# [540]	train-mae:19.53703	eval-mae:10.76204
# [541]	train-mae:19.45218	eval-mae:10.73976
# [542]	train-mae:19.36916	eval-mae:10.71578
# [543]	train-mae:19.28837	eval-mae:10.70201
# [544]	train-mae:19.20975	eval-mae:10.68385
# [545]	train-mae:19.13052	eval-mae:10.66245
# [546]	train-mae:19.05262	eval-mae:10.64497
# [547]	train-mae:18.97419	eval-mae:10.62190
# [548]	train-mae:18.89759	eval-mae:10.60489
# [549]	train-mae:18.82276	eval-mae:10.58392
# [550]	train-mae:18.74870	eval-mae:10.55260
# [551]	train-mae:18.67646	eval-mae:10.52970
# [552]	train-mae:18.60394	eval-mae:10.50158
# [553]	train-mae:18.53239	eval-mae:10.48210
# [554]	train-mae:18.46212	eval-mae:10.45984
# [555]	train-mae:18.39287	eval-mae:10.44448
# [556]	train-mae:18.32627	eval-mae:10.42709
# [557]	train-mae:18.25945	eval-mae:10.41220
# [558]	train-mae:18.19269	eval-mae:10.39115
# [559]	train-mae:18.12660	eval-mae:10.37240
# [560]	train-mae:18.06241	eval-mae:10.34889
# [561]	train-mae:18.00016	eval-mae:10.33193
# [562]	train-mae:17.93952	eval-mae:10.31629
# [563]	train-mae:17.87902	eval-mae:10.30506
# [564]	train-mae:17.82054	eval-mae:10.29374
# [565]	train-mae:17.76081	eval-mae:10.27663
# [566]	train-mae:17.70234	eval-mae:10.25604
# [567]	train-mae:17.64435	eval-mae:10.24281
# [568]	train-mae:17.58645	eval-mae:10.22187
# [569]	train-mae:17.52880	eval-mae:10.19911
# [570]	train-mae:17.47483	eval-mae:10.18382
# [571]	train-mae:17.41971	eval-mae:10.16603
# [572]	train-mae:17.36523	eval-mae:10.15080
# [573]	train-mae:17.31261	eval-mae:10.13531
# [574]	train-mae:17.26002	eval-mae:10.12089
# [575]	train-mae:17.20819	eval-mae:10.10162
# [576]	train-mae:17.15730	eval-mae:10.08617
# [577]	train-mae:17.10726	eval-mae:10.07175
# [638]	train-mae:15.12797	eval-mae:9.39538
# [639]	train-mae:15.10792	eval-mae:9.39049
# [640]	train-mae:15.08850	eval-mae:9.38289
# [641]	train-mae:15.06901	eval-mae:9.37319
# [642]	train-mae:15.04962	eval-mae:9.36619
# [643]	train-mae:15.03257	eval-mae:9.36439
# [644]	train-mae:15.01380	eval-mae:9.35583
# [645]	train-mae:14.99575	eval-mae:9.34840
# [646]	train-mae:14.97699	eval-mae:9.33970
# [647]	train-mae:14.95922	eval-mae:9.33472
# [648]	train-mae:14.94187	eval-mae:9.32844
# [649]	train-mae:14.92545	eval-mae:9.32685
# [650]	train-mae:14.90718	eval-mae:9.31780
# [651]	train-mae:14.89103	eval-mae:9.31265
# [652]	train-mae:14.87464	eval-mae:9.31017
# [653]	train-mae:14.85807	eval-mae:9.30470
# [654]	train-mae:14.84200	eval-mae:9.30036
# [655]	train-mae:14.82562	eval-mae:9.29121
# [656]	train-mae:14.80890	eval-mae:9.28498
# [657]	train-mae:14.79372	eval-mae:9.28105
# [658]	train-mae:14.77824	eval-mae:9.27632
# [659]	train-mae:14.76258	eval-mae:9.27014
# [660]	train-mae:14.74795	eval-mae:9.26395
# [661]	train-mae:14.73278	eval-mae:9.25737
# [662]	train-mae:14.71867	eval-mae:9.24990
# [663]	train-mae:14.70305	eval-mae:9.24279
# [664]	train-mae:14.68914	eval-mae:9.23772
# [665]	train-mae:14.67525	eval-mae:9.23053
# [666]	train-mae:14.66170	eval-mae:9.22298
# [667]	train-mae:14.64874	eval-mae:9.21652
# [668]	train-mae:14.63470	eval-mae:9.20833
# [669]	train-mae:14.62227	eval-mae:9.20446
# [670]	train-mae:14.60905	eval-mae:9.19809
# [671]	train-mae:14.59622	eval-mae:9.19087
# [672]	train-mae:14.58357	eval-mae:9.18486
# [673]	train-mae:14.57066	eval-mae:9.17465
# [674]	train-mae:14.55837	eval-mae:9.16733
# [675]	train-mae:14.54614	eval-mae:9.16063
# [676]	train-mae:14.53417	eval-mae:9.15410
# [677]	train-mae:14.52245	eval-mae:9.14627
# [678]	train-mae:14.51098	eval-mae:9.14123
# [679]	train-mae:14.49997	eval-mae:9.13480
# [680]	train-mae:14.48820	eval-mae:9.12902
# [681]	train-mae:14.47646	eval-mae:9.12266
# [682]	train-mae:14.46524	eval-mae:9.11818
# [683]	train-mae:14.45424	eval-mae:9.11159
# [684]	train-mae:14.44172	eval-mae:9.10419
# [685]	train-mae:14.43042	eval-mae:9.10016
# [686]	train-mae:14.41822	eval-mae:9.09480
# [687]	train-mae:14.40800	eval-mae:9.09211
# [688]	train-mae:14.39637	eval-mae:9.08522
# [689]	train-mae:14.38569	eval-mae:9.07782
# [690]	train-mae:14.37474	eval-mae:9.07078
# [691]	train-mae:14.36409	eval-mae:9.06662
# [692]	train-mae:14.35338	eval-mae:9.06090
# [693]	train-mae:14.34354	eval-mae:9.05537
# [694]	train-mae:14.33316	eval-mae:9.05011
# [695]	train-mae:14.32159	eval-mae:9.04427
# [696]	train-mae:14.31218	eval-mae:9.03835
# [697]	train-mae:14.30212	eval-mae:9.03330
# [698]	train-mae:14.29257	eval-mae:9.02905
# [699]	train-mae:14.28283	eval-mae:9.02498
# [700]	train-mae:14.27321	eval-mae:9.02191
# [701]	train-mae:14.26375	eval-mae:9.01815
# [702]	train-mae:14.25539	eval-mae:9.01727
# [703]	train-mae:14.24614	eval-mae:9.01353
# [704]	train-mae:14.23776	eval-mae:9.00831
# [705]	train-mae:14.22948	eval-mae:9.00458
# [706]	train-mae:14.22101	eval-mae:9.00120
# [707]	train-mae:14.21231	eval-mae:8.99764
# [708]	train-mae:14.20459	eval-mae:8.99401
# [709]	train-mae:14.19708	eval-mae:8.99168
# [710]	train-mae:14.18857	eval-mae:8.98959
# [711]	train-mae:14.18019	eval-mae:8.98555
# [712]	train-mae:14.17291	eval-mae:8.98200
# [713]	train-mae:14.16451	eval-mae:8.97729
# [714]	train-mae:14.15574	eval-mae:8.97317
# [715]	train-mae:14.14750	eval-mae:8.96998
# [716]	train-mae:14.13931	eval-mae:8.96656
# [717]	train-mae:14.13272	eval-mae:8.96377
# [718]	train-mae:14.12587	eval-mae:8.95851
# [719]	train-mae:14.11779	eval-mae:8.95366
# [720]	train-mae:14.11014	eval-mae:8.94865
# [721]	train-mae:14.10293	eval-mae:8.94507
# [722]	train-mae:14.09473	eval-mae:8.94091
# [723]	train-mae:14.08705	eval-mae:8.93923
# [724]	train-mae:14.08003	eval-mae:8.93546
# [725]	train-mae:14.07320	eval-mae:8.93239
# [726]	train-mae:14.06596	eval-mae:8.92806
# [727]	train-mae:14.05865	eval-mae:8.92258
# [728]	train-mae:14.05161	eval-mae:8.91868
# [729]	train-mae:14.04427	eval-mae:8.91446
# [730]	train-mae:14.03724	eval-mae:8.91131
# [731]	train-mae:14.03083	eval-mae:8.90845
# [732]	train-mae:14.02465	eval-mae:8.90779
# [733]	train-mae:14.01851	eval-mae:8.90413
# [734]	train-mae:14.01257	eval-mae:8.90112
# [735]	train-mae:14.00699	eval-mae:8.89911
# [736]	train-mae:14.00134	eval-mae:8.89758
# [737]	train-mae:13.99529	eval-mae:8.89524
# [738]	train-mae:13.98961	eval-mae:8.89398
# [739]	train-mae:13.98327	eval-mae:8.89134
# [740]	train-mae:13.97717	eval-mae:8.88867
# [741]	train-mae:13.97007	eval-mae:8.88460
# [742]	train-mae:13.96410	eval-mae:8.88287
# [743]	train-mae:13.95821	eval-mae:8.88048
# [744]	train-mae:13.95281	eval-mae:8.87980
# [745]	train-mae:13.94574	eval-mae:8.87480
# [746]	train-mae:13.93884	eval-mae:8.87426
# [747]	train-mae:13.93319	eval-mae:8.86940
# [748]	train-mae:13.92702	eval-mae:8.86516
# [749]	train-mae:13.92156	eval-mae:8.86138
# [750]	train-mae:13.91542	eval-mae:8.85714
# [751]	train-mae:13.90990	eval-mae:8.85606
# [752]	train-mae:13.90421	eval-mae:8.85380
# [753]	train-mae:13.89864	eval-mae:8.85221
# [754]	train-mae:13.89273	eval-mae:8.84841
# [755]	train-mae:13.88720	eval-mae:8.84669
# [756]	train-mae:13.88182	eval-mae:8.84532
# [757]	train-mae:13.87680	eval-mae:8.84189
# [758]	train-mae:13.87156	eval-mae:8.83994
# [759]	train-mae:13.86598	eval-mae:8.83668
# [760]	train-mae:13.86032	eval-mae:8.83314
# [761]	train-mae:13.85435	eval-mae:8.83001
# [762]	train-mae:13.84825	eval-mae:8.82525
# [763]	train-mae:13.84272	eval-mae:8.82201
# [764]	train-mae:13.83726	eval-mae:8.81780
# [765]	train-mae:13.83018	eval-mae:8.81378
# [766]	train-mae:13.82446	eval-mae:8.81086
# [767]	train-mae:13.82005	eval-mae:8.80717
# [768]	train-mae:13.81465	eval-mae:8.80456
# [769]	train-mae:13.80807	eval-mae:8.80164
# [770]	train-mae:13.80204	eval-mae:8.79878
# [771]	train-mae:13.79640	eval-mae:8.79611
# [772]	train-mae:13.79194	eval-mae:8.79373
# [773]	train-mae:13.78613	eval-mae:8.79149
# [774]	train-mae:13.77990	eval-mae:8.78871
# [775]	train-mae:13.77515	eval-mae:8.78822
# [776]	train-mae:13.76956	eval-mae:8.78535
# [777]	train-mae:13.76358	eval-mae:8.78247
# [778]	train-mae:13.75864	eval-mae:8.77998
# [779]	train-mae:13.75447	eval-mae:8.77729
# [780]	train-mae:13.75046	eval-mae:8.77612
# [781]	train-mae:13.74510	eval-mae:8.77380
# [782]	train-mae:13.74031	eval-mae:8.77227
# [783]	train-mae:13.73570	eval-mae:8.76963
# [784]	train-mae:13.73161	eval-mae:8.76705
# [785]	train-mae:13.72679	eval-mae:8.76353
# [786]	train-mae:13.72173	eval-mae:8.76165
# [787]	train-mae:13.71668	eval-mae:8.75841
# [788]	train-mae:13.71283	eval-mae:8.75766
# [789]	train-mae:13.70895	eval-mae:8.75568
# [790]	train-mae:13.70495	eval-mae:8.75525
# [791]	train-mae:13.70049	eval-mae:8.75233
# [792]	train-mae:13.69588	eval-mae:8.75002
# [793]	train-mae:13.69158	eval-mae:8.74911
# [794]	train-mae:13.68647	eval-mae:8.74708
# [795]	train-mae:13.68203	eval-mae:8.74643
# [796]	train-mae:13.67745	eval-mae:8.74456
# [797]	train-mae:13.67217	eval-mae:8.74351
# [798]	train-mae:13.66601	eval-mae:8.73903
# [799]	train-mae:13.66118	eval-mae:8.73872
# [800]	train-mae:13.65622	eval-mae:8.73574
# [801]	train-mae:13.65177	eval-mae:8.73366
# [802]	train-mae:13.64732	eval-mae:8.73207
# [803]	train-mae:13.64299	eval-mae:8.72991
# [804]	train-mae:13.63808	eval-mae:8.72770
# [805]	train-mae:13.63400	eval-mae:8.72630
# [806]	train-mae:13.63058	eval-mae:8.72640
# [807]	train-mae:13.62606	eval-mae:8.72514
# [808]	train-mae:13.62277	eval-mae:8.72397
# [809]	train-mae:13.61929	eval-mae:8.72328
# [810]	train-mae:13.61513	eval-mae:8.72158
# [811]	train-mae:13.61081	eval-mae:8.71821
# [812]	train-mae:13.60658	eval-mae:8.71655
# [813]	train-mae:13.60211	eval-mae:8.71421
# [814]	train-mae:13.59810	eval-mae:8.71317
# [815]	train-mae:13.59410	eval-mae:8.71127
# [816]	train-mae:13.58930	eval-mae:8.70825
# [817]	train-mae:13.58464	eval-mae:8.70541
# [818]	train-mae:13.58028	eval-mae:8.70435
# [819]	train-mae:13.57601	eval-mae:8.70282
# [820]	train-mae:13.57288	eval-mae:8.69976
# [821]	train-mae:13.56888	eval-mae:8.69833
# [822]	train-mae:13.56446	eval-mae:8.69680
# [823]	train-mae:13.56092	eval-mae:8.69539
# [824]	train-mae:13.55646	eval-mae:8.69240
# [825]	train-mae:13.55352	eval-mae:8.69182
# [826]	train-mae:13.55004	eval-mae:8.68966
# [827]	train-mae:13.54640	eval-mae:8.68845
# [828]	train-mae:13.54288	eval-mae:8.68715
# [829]	train-mae:13.53824	eval-mae:8.68539
# [830]	train-mae:13.53434	eval-mae:8.68019
# [831]	train-mae:13.53136	eval-mae:8.67866
# [832]	train-mae:13.52785	eval-mae:8.67613
# [833]	train-mae:13.52524	eval-mae:8.67499
# [834]	train-mae:13.52053	eval-mae:8.67187
# [835]	train-mae:13.51703	eval-mae:8.67082
# [836]	train-mae:13.51207	eval-mae:8.66845
# [837]	train-mae:13.50887	eval-mae:8.66737
# [838]	train-mae:13.50540	eval-mae:8.66646
# [839]	train-mae:13.50250	eval-mae:8.66450
# [840]	train-mae:13.49791	eval-mae:8.66320
# [841]	train-mae:13.49518	eval-mae:8.66304
# [842]	train-mae:13.49118	eval-mae:8.66113
# [843]	train-mae:13.48765	eval-mae:8.65975
# [844]	train-mae:13.48291	eval-mae:8.65736
# [845]	train-mae:13.47960	eval-mae:8.65521
# [846]	train-mae:13.47535	eval-mae:8.65328
# [847]	train-mae:13.47069	eval-mae:8.65127
# [848]	train-mae:13.46746	eval-mae:8.65012
# [849]	train-mae:13.46329	eval-mae:8.64751
# [850]	train-mae:13.46007	eval-mae:8.64676
# [851]	train-mae:13.45695	eval-mae:8.64543
# [852]	train-mae:13.45304	eval-mae:8.64425
# [853]	train-mae:13.44907	eval-mae:8.64287
# [854]	train-mae:13.44634	eval-mae:8.64172
# [855]	train-mae:13.44315	eval-mae:8.64119
# [856]	train-mae:13.43993	eval-mae:8.64006
# [857]	train-mae:13.43670	eval-mae:8.63844
# [858]	train-mae:13.43335	eval-mae:8.63779
# [859]	train-mae:13.42870	eval-mae:8.63535
# [860]	train-mae:13.42541	eval-mae:8.63307
# [861]	train-mae:13.42220	eval-mae:8.63140
# [862]	train-mae:13.41919	eval-mae:8.63045
# [863]	train-mae:13.41670	eval-mae:8.63010
# [864]	train-mae:13.41373	eval-mae:8.62843
# [865]	train-mae:13.41022	eval-mae:8.62678
# [866]	train-mae:13.40676	eval-mae:8.62651
# [867]	train-mae:13.40348	eval-mae:8.62540
# [868]	train-mae:13.40014	eval-mae:8.62405
# [869]	train-mae:13.39740	eval-mae:8.62239
# [870]	train-mae:13.39374	eval-mae:8.62135
# [871]	train-mae:13.39003	eval-mae:8.61991
# [872]	train-mae:13.38705	eval-mae:8.61862
# [873]	train-mae:13.38394	eval-mae:8.61750
# [874]	train-mae:13.38025	eval-mae:8.61578
# [875]	train-mae:13.37736	eval-mae:8.61335
# [876]	train-mae:13.37431	eval-mae:8.61187
# [877]	train-mae:13.37196	eval-mae:8.61142
# [878]	train-mae:13.36910	eval-mae:8.61073
# [879]	train-mae:13.36626	eval-mae:8.60977
# [880]	train-mae:13.36288	eval-mae:8.60837
# [881]	train-mae:13.35940	eval-mae:8.60797
# [882]	train-mae:13.35638	eval-mae:8.60690
# [883]	train-mae:13.35312	eval-mae:8.60599
# [884]	train-mae:13.35031	eval-mae:8.60469
# [885]	train-mae:13.34702	eval-mae:8.60466
# [886]	train-mae:13.34443	eval-mae:8.60459
# [887]	train-mae:13.34124	eval-mae:8.60408
# [888]	train-mae:13.33833	eval-mae:8.60371
# [889]	train-mae:13.33522	eval-mae:8.60346
# [890]	train-mae:13.33245	eval-mae:8.60220
# [891]	train-mae:13.33025	eval-mae:8.60192
# [892]	train-mae:13.32758	eval-mae:8.60092
# [893]	train-mae:13.32447	eval-mae:8.60005
# [894]	train-mae:13.32146	eval-mae:8.59928
# [895]	train-mae:13.31804	eval-mae:8.59804
# [896]	train-mae:13.31544	eval-mae:8.59679
# [897]	train-mae:13.31228	eval-mae:8.59596
# [898]	train-mae:13.30955	eval-mae:8.59511
# [899]	train-mae:13.30663	eval-mae:8.59466
# [900]	train-mae:13.30402	eval-mae:8.59340
# [901]	train-mae:13.30094	eval-mae:8.59339
# [902]	train-mae:13.29835	eval-mae:8.59264
# [903]	train-mae:13.29521	eval-mae:8.59162
# [904]	train-mae:13.29196	eval-mae:8.58948
# [905]	train-mae:13.28936	eval-mae:8.58712
# [906]	train-mae:13.28700	eval-mae:8.58663
# [907]	train-mae:13.28462	eval-mae:8.58500
# [908]	train-mae:13.28133	eval-mae:8.58328
# [909]	train-mae:13.27820	eval-mae:8.58238
# [910]	train-mae:13.27541	eval-mae:8.58153
# [911]	train-mae:13.27285	eval-mae:8.58098
# [912]	train-mae:13.27074	eval-mae:8.58042
# [913]	train-mae:13.26866	eval-mae:8.57969
# [914]	train-mae:13.26541	eval-mae:8.57906
# [915]	train-mae:13.26320	eval-mae:8.57842
# [916]	train-mae:13.26006	eval-mae:8.57798
# [917]	train-mae:13.25771	eval-mae:8.57759
# [918]	train-mae:13.25439	eval-mae:8.57726
# [919]	train-mae:13.25157	eval-mae:8.57622
# [920]	train-mae:13.24822	eval-mae:8.57326
# [921]	train-mae:13.24560	eval-mae:8.57281
# [922]	train-mae:13.24378	eval-mae:8.57178
# [923]	train-mae:13.24169	eval-mae:8.57120
# [924]	train-mae:13.23868	eval-mae:8.56736
# [925]	train-mae:13.23602	eval-mae:8.56608
# [926]	train-mae:13.23324	eval-mae:8.56117
# [927]	train-mae:13.23112	eval-mae:8.56039
# [928]	train-mae:13.22923	eval-mae:8.55919
# [929]	train-mae:13.22662	eval-mae:8.55824
# [930]	train-mae:13.22394	eval-mae:8.55780
# [931]	train-mae:13.22181	eval-mae:8.55776
# [932]	train-mae:13.21968	eval-mae:8.55768
# [933]	train-mae:13.21714	eval-mae:8.55709
# [934]	train-mae:13.21498	eval-mae:8.55689
# [935]	train-mae:13.21213	eval-mae:8.55422
# [936]	train-mae:13.20956	eval-mae:8.55224
# [937]	train-mae:13.20688	eval-mae:8.55226
# [938]	train-mae:13.20507	eval-mae:8.55223
# [939]	train-mae:13.20325	eval-mae:8.55120
# [940]	train-mae:13.20114	eval-mae:8.55007
# [941]	train-mae:13.19891	eval-mae:8.54819
# [942]	train-mae:13.19628	eval-mae:8.54779
# [943]	train-mae:13.19356	eval-mae:8.54776
# [944]	train-mae:13.19139	eval-mae:8.54800
# [945]	train-mae:13.18865	eval-mae:8.54745
# [946]	train-mae:13.18708	eval-mae:8.54722
# [947]	train-mae:13.18504	eval-mae:8.54659
# [948]	train-mae:13.18208	eval-mae:8.54578
# [949]	train-mae:13.17963	eval-mae:8.54493
# [950]	train-mae:13.17695	eval-mae:8.54400
# [951]	train-mae:13.17484	eval-mae:8.54338
# [952]	train-mae:13.17241	eval-mae:8.54194
# [953]	train-mae:13.17009	eval-mae:8.54175
# [954]	train-mae:13.16777	eval-mae:8.54130
# [955]	train-mae:13.16526	eval-mae:8.54087
# [956]	train-mae:13.16233	eval-mae:8.54062
# [957]	train-mae:13.15990	eval-mae:8.53971
# [958]	train-mae:13.15792	eval-mae:8.53844
# [959]	train-mae:13.15604	eval-mae:8.53770
# [960]	train-mae:13.15384	eval-mae:8.53736
# [961]	train-mae:13.15190	eval-mae:8.53662
# [962]	train-mae:13.14917	eval-mae:8.53669
# [963]	train-mae:13.14660	eval-mae:8.53640
# [964]	train-mae:13.14368	eval-mae:8.53514
# [965]	train-mae:13.14118	eval-mae:8.53501
# [966]	train-mae:13.13904	eval-mae:8.53446
# [967]	train-mae:13.13705	eval-mae:8.53411
# [968]	train-mae:13.13494	eval-mae:8.53286
# [969]	train-mae:13.13312	eval-mae:8.53136
# [970]	train-mae:13.13064	eval-mae:8.53097
# [971]	train-mae:13.12806	eval-mae:8.53003
# [972]	train-mae:13.12566	eval-mae:8.52952
# [973]	train-mae:13.12354	eval-mae:8.52924
# [974]	train-mae:13.12126	eval-mae:8.52872
# [975]	train-mae:13.11905	eval-mae:8.52848
# [976]	train-mae:13.11732	eval-mae:8.52878
# [977]	train-mae:13.11468	eval-mae:8.52869
# [978]	train-mae:13.11270	eval-mae:8.52605
# [979]	train-mae:13.11095	eval-mae:8.52601
# [980]	train-mae:13.10780	eval-mae:8.52483
# [981]	train-mae:13.10606	eval-mae:8.52431
# [982]	train-mae:13.10456	eval-mae:8.52386
# [983]	train-mae:13.10250	eval-mae:8.52269
# [984]	train-mae:13.09966	eval-mae:8.52253
# [985]	train-mae:13.09761	eval-mae:8.52259
# [986]	train-mae:13.09574	eval-mae:8.52143
# [987]	train-mae:13.09393	eval-mae:8.52066
# [988]	train-mae:13.09259	eval-mae:8.52043
# [989]	train-mae:13.09072	eval-mae:8.52030
# [990]	train-mae:13.08829	eval-mae:8.52009
# [991]	train-mae:13.08651	eval-mae:8.51972
# [992]	train-mae:13.08434	eval-mae:8.51967
# [993]	train-mae:13.08213	eval-mae:8.51877
# [994]	train-mae:13.08010	eval-mae:8.51843
# [995]	train-mae:13.07848	eval-mae:8.51798
# [996]	train-mae:13.07599	eval-mae:8.51683
# [997]	train-mae:13.07360	eval-mae:8.51612
# [998]	train-mae:13.07113	eval-mae:8.51584
# [999]	train-mae:13.06865	eval-mae:8.51550
# [1000]	train-mae:13.06622	eval-mae:8.51534
# [1001]	train-mae:13.06424	eval-mae:8.51425
# [1002]	train-mae:13.06222	eval-mae:8.51332
# [1003]	train-mae:13.06036	eval-mae:8.51326
# [1004]	train-mae:13.05856	eval-mae:8.51334
# [1005]	train-mae:13.05582	eval-mae:8.51353
# [1006]	train-mae:13.05354	eval-mae:8.51335
# [1007]	train-mae:13.05186	eval-mae:8.51264
# [1008]	train-mae:13.04991	eval-mae:8.51171
# [1009]	train-mae:13.04775	eval-mae:8.51159
# [1010]	train-mae:13.04545	eval-mae:8.51113
# [1011]	train-mae:13.04391	eval-mae:8.51109
# [1012]	train-mae:13.04185	eval-mae:8.51099
# [1013]	train-mae:13.03971	eval-mae:8.51093
# [1014]	train-mae:13.03765	eval-mae:8.51033
# [1015]	train-mae:13.03590	eval-mae:8.50970
# [1016]	train-mae:13.03345	eval-mae:8.50780
# [1017]	train-mae:13.03156	eval-mae:8.50782
# [1018]	train-mae:13.02969	eval-mae:8.50761
# [1019]	train-mae:13.02796	eval-mae:8.50745
# [1020]	train-mae:13.02639	eval-mae:8.50698
# [1021]	train-mae:13.02461	eval-mae:8.50612
# [1022]	train-mae:13.02252	eval-mae:8.50499
# [1023]	train-mae:13.02050	eval-mae:8.50476
# [1024]	train-mae:13.01799	eval-mae:8.50418
# [1025]	train-mae:13.01603	eval-mae:8.50417
# [1026]	train-mae:13.01421	eval-mae:8.50388
# [1027]	train-mae:13.01245	eval-mae:8.50332
# [1028]	train-mae:13.01004	eval-mae:8.50309
# [1029]	train-mae:13.00783	eval-mae:8.50306
# [1030]	train-mae:13.00585	eval-mae:8.50199
# [1031]	train-mae:13.00395	eval-mae:8.50115
# [1032]	train-mae:13.00204	eval-mae:8.50057
# [1033]	train-mae:13.00005	eval-mae:8.50011
# [1034]	train-mae:12.99813	eval-mae:8.49909
# [1035]	train-mae:12.99614	eval-mae:8.49905
# [1036]	train-mae:12.99410	eval-mae:8.49853
# [1037]	train-mae:12.99155	eval-mae:8.49731
# [1038]	train-mae:12.98911	eval-mae:8.49682
# [1039]	train-mae:12.98679	eval-mae:8.49651
# [1040]	train-mae:12.98440	eval-mae:8.49558
# [1041]	train-mae:12.98267	eval-mae:8.49495
# [1042]	train-mae:12.98039	eval-mae:8.49477
# [1043]	train-mae:12.97900	eval-mae:8.49451
# [1044]	train-mae:12.97615	eval-mae:8.49435
# [1045]	train-mae:12.97402	eval-mae:8.49363
# [1046]	train-mae:12.97261	eval-mae:8.49349
# [1047]	train-mae:12.97056	eval-mae:8.49343
# [1048]	train-mae:12.96864	eval-mae:8.49266
# [1049]	train-mae:12.96730	eval-mae:8.49183
# [1050]	train-mae:12.96542	eval-mae:8.49105
# [1051]	train-mae:12.96379	eval-mae:8.49117
# [1052]	train-mae:12.96202	eval-mae:8.49110
# [1053]	train-mae:12.96017	eval-mae:8.49098
# [1054]	train-mae:12.95796	eval-mae:8.49034
# [1055]	train-mae:12.95615	eval-mae:8.49043
# [1056]	train-mae:12.95431	eval-mae:8.49014
# [1057]	train-mae:12.95254	eval-mae:8.48978
# [1058]	train-mae:12.95069	eval-mae:8.48911
# [1059]	train-mae:12.94823	eval-mae:8.48952
# [1060]	train-mae:12.94592	eval-mae:8.48805
# [1061]	train-mae:12.94428	eval-mae:8.48805
# [1062]	train-mae:12.94261	eval-mae:8.48824
# [1063]	train-mae:12.94113	eval-mae:8.48844
# [1064]	train-mae:12.93984	eval-mae:8.48752
# [1065]	train-mae:12.93845	eval-mae:8.48709
# [1066]	train-mae:12.93656	eval-mae:8.48697
# [1067]	train-mae:12.93479	eval-mae:8.48652
# [1068]	train-mae:12.93327	eval-mae:8.48629
# [1069]	train-mae:12.93176	eval-mae:8.48546
# [1070]	train-mae:12.92982	eval-mae:8.48532
# [1071]	train-mae:12.92770	eval-mae:8.48518
# [1072]	train-mae:12.92580	eval-mae:8.48477
# [1073]	train-mae:12.92385	eval-mae:8.48306
# [1074]	train-mae:12.92211	eval-mae:8.48288
# [1075]	train-mae:12.91963	eval-mae:8.48259
# [1076]	train-mae:12.91734	eval-mae:8.48147
# [1077]	train-mae:12.91586	eval-mae:8.48085
# [1078]	train-mae:12.91436	eval-mae:8.48075
# [1079]	train-mae:12.91244	eval-mae:8.48012
# [1080]	train-mae:12.91003	eval-mae:8.47973
# [1081]	train-mae:12.90860	eval-mae:8.47933
# [1082]	train-mae:12.90681	eval-mae:8.47932
# [1083]	train-mae:12.90453	eval-mae:8.47906
# [1084]	train-mae:12.90226	eval-mae:8.47898
# [1085]	train-mae:12.90038	eval-mae:8.47841
# [1086]	train-mae:12.89854	eval-mae:8.47739
# [1087]	train-mae:12.89610	eval-mae:8.47717
# [1088]	train-mae:12.89465	eval-mae:8.47718
# [1089]	train-mae:12.89176	eval-mae:8.47596
# [1090]	train-mae:12.88946	eval-mae:8.47009
# [1091]	train-mae:12.88740	eval-mae:8.46942
# [1092]	train-mae:12.88565	eval-mae:8.46806
# [1093]	train-mae:12.88352	eval-mae:8.46723
# [1094]	train-mae:12.88154	eval-mae:8.46723
# [1095]	train-mae:12.87967	eval-mae:8.46681
# [1096]	train-mae:12.87804	eval-mae:8.46630
# [1097]	train-mae:12.87593	eval-mae:8.46607
# [1098]	train-mae:12.87374	eval-mae:8.46563
# [1099]	train-mae:12.87158	eval-mae:8.46542
# [1100]	train-mae:12.86939	eval-mae:8.46472
# [1101]	train-mae:12.86784	eval-mae:8.46474
# [1102]	train-mae:12.86606	eval-mae:8.46386
# [1103]	train-mae:12.86438	eval-mae:8.46270
# [1104]	train-mae:12.86244	eval-mae:8.46225
# [1105]	train-mae:12.86106	eval-mae:8.46150
# [1106]	train-mae:12.85867	eval-mae:8.46153
# [1107]	train-mae:12.85631	eval-mae:8.46128
# [1108]	train-mae:12.85477	eval-mae:8.46112
# [1109]	train-mae:12.85264	eval-mae:8.46046
# ...
# [1628]	train-mae:12.08447	eval-mae:8.21045
# [1629]	train-mae:12.08330	eval-mae:8.21034
# [1630]	train-mae:12.08195	eval-mae:8.21004
# [1631]	train-mae:12.08026	eval-mae:8.20914
# [1632]	train-mae:12.07921	eval-mae:8.20909
# [1633]	train-mae:12.07773	eval-mae:8.20912
# [1634]	train-mae:12.07721	eval-mae:8.20914
# [1635]	train-mae:12.07552	eval-mae:8.20906
# [1636]	train-mae:12.07433	eval-mae:8.20898
# [1637]	train-mae:12.07244	eval-mae:8.20803
# [1638]	train-mae:12.07070	eval-mae:8.20729
# [1639]	train-mae:12.06927	eval-mae:8.20606
# [1640]	train-mae:12.06827	eval-mae:8.20571
# [1641]	train-mae:12.06695	eval-mae:8.20529
# [1642]	train-mae:12.06587	eval-mae:8.20514
# [1643]	train-mae:12.06476	eval-mae:8.20516
# [1644]	train-mae:12.06357	eval-mae:8.20506
# [1645]	train-mae:12.06230	eval-mae:8.20445
# [1646]	train-mae:12.06100	eval-mae:8.20433
# [1647]	train-mae:12.05975	eval-mae:8.20413
# [1648]	train-mae:12.05879	eval-mae:8.20411
# [1649]	train-mae:12.05717	eval-mae:8.20405
# [1650]	train-mae:12.05595	eval-mae:8.20408
# [1651]	train-mae:12.05434	eval-mae:8.20401
# [1652]	train-mae:12.05363	eval-mae:8.20382
# [1653]	train-mae:12.05246	eval-mae:8.20380
# [1654]	train-mae:12.05153	eval-mae:8.20382
# [1655]	train-mae:12.05054	eval-mae:8.20361
# [1656]	train-mae:12.04922	eval-mae:8.20314
# [1657]	train-mae:12.04793	eval-mae:8.20261
# [1658]	train-mae:12.04702	eval-mae:8.20232
# [1659]	train-mae:12.04604	eval-mae:8.20090
# [1660]	train-mae:12.04498	eval-mae:8.20080
# [1661]	train-mae:12.04377	eval-mae:8.20048
# [1662]	train-mae:12.04268	eval-mae:8.20055
# [1663]	train-mae:12.04128	eval-mae:8.19931
# [1664]	train-mae:12.04032	eval-mae:8.19931
# [1665]	train-mae:12.03933	eval-mae:8.19931
# [1666]	train-mae:12.03782	eval-mae:8.19931
# [1667]	train-mae:12.03638	eval-mae:8.19912
# [1668]	train-mae:12.03505	eval-mae:8.19903
# [1669]	train-mae:12.03360	eval-mae:8.19820
# [1670]	train-mae:12.03228	eval-mae:8.19770
# [1671]	train-mae:12.03053	eval-mae:8.19759
# [1672]	train-mae:12.02940	eval-mae:8.19759
# [1673]	train-mae:12.02818	eval-mae:8.19731
# [1674]	train-mae:12.02686	eval-mae:8.19732
# [1675]	train-mae:12.02571	eval-mae:8.19742
# [1676]	train-mae:12.02471	eval-mae:8.19729
# [1677]	train-mae:12.02376	eval-mae:8.19731
# [1678]	train-mae:12.02262	eval-mae:8.19740
# [1679]	train-mae:12.02180	eval-mae:8.19713
# [1680]	train-mae:12.01983	eval-mae:8.19231
# [1681]	train-mae:12.01816	eval-mae:8.19227
# [1682]	train-mae:12.01717	eval-mae:8.19210
# [1683]	train-mae:12.01616	eval-mae:8.19203
# [1684]	train-mae:12.01509	eval-mae:8.19182
# [1685]	train-mae:12.01420	eval-mae:8.19182
# [1686]	train-mae:12.01289	eval-mae:8.19182
# [1687]	train-mae:12.01192	eval-mae:8.19174
# [1688]	train-mae:12.01092	eval-mae:8.19175
# [1689]	train-mae:12.00979	eval-mae:8.19173
# [1690]	train-mae:12.00811	eval-mae:8.19192
# [1691]	train-mae:12.00618	eval-mae:8.18686
# [1692]	train-mae:12.00525	eval-mae:8.18686
# [1693]	train-mae:12.00383	eval-mae:8.18684
# [1694]	train-mae:12.00282	eval-mae:8.18678
# [1695]	train-mae:12.00170	eval-mae:8.18676
# [1696]	train-mae:12.00069	eval-mae:8.18678
# [1697]	train-mae:11.99906	eval-mae:8.18678
# [1698]	train-mae:11.99799	eval-mae:8.18676
# [1699]	train-mae:11.99682	eval-mae:8.18657
# [1700]	train-mae:11.99566	eval-mae:8.18661
# [1701]	train-mae:11.99451	eval-mae:8.18633
# [1702]	train-mae:11.99304	eval-mae:8.18546
# [1703]	train-mae:11.99193	eval-mae:8.18538
# [1704]	train-mae:11.99063	eval-mae:8.18535
# [1705]	train-mae:11.98947	eval-mae:8.18532
# [1706]	train-mae:11.98849	eval-mae:8.18522
# [1707]	train-mae:11.98783	eval-mae:8.18522
# [1708]	train-mae:11.98699	eval-mae:8.18522
# [1709]	train-mae:11.98603	eval-mae:8.18484
# [1710]	train-mae:11.98502	eval-mae:8.18452
# [1711]	train-mae:11.98403	eval-mae:8.18464
# [1712]	train-mae:11.98274	eval-mae:8.18466
# [1713]	train-mae:11.98157	eval-mae:8.18466
# [1714]	train-mae:11.98048	eval-mae:8.18432
# [1715]	train-mae:11.97900	eval-mae:8.18362
# [1716]	train-mae:11.97802	eval-mae:8.18363
# [1717]	train-mae:11.97698	eval-mae:8.18359
# [1718]	train-mae:11.97594	eval-mae:8.18332
# [1719]	train-mae:11.97482	eval-mae:8.18330
# [1720]	train-mae:11.97356	eval-mae:8.18301
# [1721]	train-mae:11.97203	eval-mae:8.18180
# [1722]	train-mae:11.97070	eval-mae:8.18109
# [1723]	train-mae:11.96945	eval-mae:8.18014
# [1724]	train-mae:11.96837	eval-mae:8.17996
# [1725]	train-mae:11.96746	eval-mae:8.17973
# [1726]	train-mae:11.96563	eval-mae:8.17962
# [1727]	train-mae:11.96455	eval-mae:8.17907
# [1728]	train-mae:11.96319	eval-mae:8.17884
# [1729]	train-mae:11.96188	eval-mae:8.17565
# [1730]	train-mae:11.96093	eval-mae:8.17562
# [1731]	train-mae:11.96037	eval-mae:8.17567
# [1732]	train-mae:11.95982	eval-mae:8.17557
# [1733]	train-mae:11.95891	eval-mae:8.17526
# [1734]	train-mae:11.95783	eval-mae:8.17492
# [1735]	train-mae:11.95710	eval-mae:8.17458
# [1736]	train-mae:11.95626	eval-mae:8.17456
# [1737]	train-mae:11.95512	eval-mae:8.17455
# [1738]	train-mae:11.95393	eval-mae:8.17424
# [1739]	train-mae:11.95258	eval-mae:8.17422
# [1740]	train-mae:11.95153	eval-mae:8.17422
# [1741]	train-mae:11.95071	eval-mae:8.17430
# [1799]	train-mae:11.88504	eval-mae:8.16410
# [1800]	train-mae:11.88422	eval-mae:8.16398
# [1801]	train-mae:11.88274	eval-mae:8.16390
# [1802]	train-mae:11.88163	eval-mae:8.16286
# [1803]	train-mae:11.88067	eval-mae:8.16287
# [1804]	train-mae:11.87978	eval-mae:8.16289
# [1805]	train-mae:11.87858	eval-mae:8.16259
# [1806]	train-mae:11.87793	eval-mae:8.16259
# [1807]	train-mae:11.87668	eval-mae:8.16139
# [1808]	train-mae:11.87531	eval-mae:8.16109
# [1809]	train-mae:11.87454	eval-mae:8.16109
# [1810]	train-mae:11.87372	eval-mae:8.16041
# [1811]	train-mae:11.87267	eval-mae:8.16011
# [1812]	train-mae:11.87134	eval-mae:8.15998
# [1813]	train-mae:11.86996	eval-mae:8.16000
# [1814]	train-mae:11.86888	eval-mae:8.16000
# [1815]	train-mae:11.86724	eval-mae:8.15965
# [1816]	train-mae:11.86559	eval-mae:8.15390
# [1817]	train-mae:11.86439	eval-mae:8.15407
# [1818]	train-mae:11.86306	eval-mae:8.15438
# [1819]	train-mae:11.86222	eval-mae:8.15434
# [1820]	train-mae:11.86125	eval-mae:8.15434
# [1821]	train-mae:11.86037	eval-mae:8.15416
# [1822]	train-mae:11.85928	eval-mae:8.15404
# [1823]	train-mae:11.85823	eval-mae:8.15400
# [1824]	train-mae:11.85729	eval-mae:8.15399
# [1825]	train-mae:11.85627	eval-mae:8.15400
# [1826]	train-mae:11.85488	eval-mae:8.15331
# [1827]	train-mae:11.85369	eval-mae:8.15325
# [1828]	train-mae:11.85247	eval-mae:8.15274
# [1829]	train-mae:11.85190	eval-mae:8.15272
# [1830]	train-mae:11.85055	eval-mae:8.15235
# [1831]	train-mae:11.84952	eval-mae:8.15225
# [1832]	train-mae:11.84844	eval-mae:8.15225
# [1833]	train-mae:11.84710	eval-mae:8.15216
# [1834]	train-mae:11.84592	eval-mae:8.15044
# [1835]	train-mae:11.84500	eval-mae:8.15044
# [1836]	train-mae:11.84347	eval-mae:8.15042
# [1837]	train-mae:11.84242	eval-mae:8.15042
# [1838]	train-mae:11.84126	eval-mae:8.15045
# [1839]	train-mae:11.84026	eval-mae:8.15043
# [1840]	train-mae:11.83898	eval-mae:8.15050
# [1841]	train-mae:11.83712	eval-mae:8.15038
# [1842]	train-mae:11.83577	eval-mae:8.15022
# [1843]	train-mae:11.83386	eval-mae:8.14676
# [1844]	train-mae:11.83271	eval-mae:8.14643
# [1845]	train-mae:11.83141	eval-mae:8.14632
# [1846]	train-mae:11.83001	eval-mae:8.14330
# [1847]	train-mae:11.82851	eval-mae:8.14237
# [1848]	train-mae:11.82687	eval-mae:8.13869
# [1849]	train-mae:11.82583	eval-mae:8.13853
# [1850]	train-mae:11.82487	eval-mae:8.13853
# [1851]	train-mae:11.82364	eval-mae:8.13826
# [1852]	train-mae:11.82269	eval-mae:8.13817
# [1853]	train-mae:11.82185	eval-mae:8.13819
# [1854]	train-mae:11.82027	eval-mae:8.13814
# [1855]	train-mae:11.81881	eval-mae:8.13523
# [1856]	train-mae:11.81762	eval-mae:8.13472
# [1857]	train-mae:11.81625	eval-mae:8.13411
# [1858]	train-mae:11.81526	eval-mae:8.13392
# [1859]	train-mae:11.81386	eval-mae:8.13385
# [1860]	train-mae:11.81331	eval-mae:8.13384
# [1861]	train-mae:11.81247	eval-mae:8.13379
# [1862]	train-mae:11.81125	eval-mae:8.13375
# [1863]	train-mae:11.81000	eval-mae:8.13371
# [1864]	train-mae:11.80919	eval-mae:8.13357
# [1865]	train-mae:11.80774	eval-mae:8.13178
# [1866]	train-mae:11.80640	eval-mae:8.13141
# [1867]	train-mae:11.80535	eval-mae:8.13141
# [1868]	train-mae:11.80430	eval-mae:8.13141
# [1869]	train-mae:11.80267	eval-mae:8.13137
# [1870]	train-mae:11.80136	eval-mae:8.13061
# [1871]	train-mae:11.80000	eval-mae:8.13061
# [1872]	train-mae:11.79923	eval-mae:8.13060
# [1873]	train-mae:11.79822	eval-mae:8.13060
# [1874]	train-mae:11.79706	eval-mae:8.13060
# [1875]	train-mae:11.79619	eval-mae:8.13002
# [1876]	train-mae:11.79534	eval-mae:8.13002
# [1877]	train-mae:11.79442	eval-mae:8.13002
# [1878]	train-mae:11.79318	eval-mae:8.13005
# [1879]	train-mae:11.79221	eval-mae:8.13004
# [1880]	train-mae:11.79119	eval-mae:8.13004
# [1881]	train-mae:11.78940	eval-mae:8.12780
# [1882]	train-mae:11.78855	eval-mae:8.12774
# [1883]	train-mae:11.78769	eval-mae:8.12773
# [1884]	train-mae:11.78687	eval-mae:8.12604
# [1885]	train-mae:11.78562	eval-mae:8.12583
# [1886]	train-mae:11.78448	eval-mae:8.12585
# [1887]	train-mae:11.78332	eval-mae:8.12572
# [1888]	train-mae:11.78233	eval-mae:8.12572
# [1889]	train-mae:11.78099	eval-mae:8.12577
# [1890]	train-mae:11.78023	eval-mae:8.12548
# [1891]	train-mae:11.77919	eval-mae:8.12570
# [1892]	train-mae:11.77832	eval-mae:8.12571
# [1893]	train-mae:11.77757	eval-mae:8.12569
# [1894]	train-mae:11.77694	eval-mae:8.12542
# [1895]	train-mae:11.77568	eval-mae:8.12507
# [1896]	train-mae:11.77436	eval-mae:8.12278
# [1897]	train-mae:11.77344	eval-mae:8.12281
# [1898]	train-mae:11.77266	eval-mae:8.12276
# [1899]	train-mae:11.77213	eval-mae:8.12276
# [1900]	train-mae:11.77078	eval-mae:8.12272
# [1901]	train-mae:11.76989	eval-mae:8.12272
# [1902]	train-mae:11.76857	eval-mae:8.11972
# [1903]	train-mae:11.76733	eval-mae:8.11970
# [1904]	train-mae:11.76626	eval-mae:8.11937
# [1905]	train-mae:11.76502	eval-mae:8.11937
# [1906]	train-mae:11.76439	eval-mae:8.11937
# [1907]	train-mae:11.76320	eval-mae:8.11939
# [1908]	train-mae:11.76247	eval-mae:8.11953
# [1909]	train-mae:11.76152	eval-mae:8.11957
# [1910]	train-mae:11.76068	eval-mae:8.11956
# [1911]	train-mae:11.75977	eval-mae:8.11956
# [1912]	train-mae:11.75882	eval-mae:8.11922
# [1913]	train-mae:11.75788	eval-mae:8.11894
# [1914]	train-mae:11.75666	eval-mae:8.11892
# [1915]	train-mae:11.75548	eval-mae:8.11857
# [1916]	train-mae:11.75447	eval-mae:8.11830
# [1917]	train-mae:11.75355	eval-mae:8.11823
# [1918]	train-mae:11.75255	eval-mae:8.11809
# [1919]	train-mae:11.75105	eval-mae:8.11764
# [1920]	train-mae:11.74944	eval-mae:8.11734
# [1921]	train-mae:11.74828	eval-mae:8.11704
# [1922]	train-mae:11.74743	eval-mae:8.11707
# [1923]	train-mae:11.74625	eval-mae:8.11707
# [1924]	train-mae:11.74512	eval-mae:8.11701
# [1925]	train-mae:11.74415	eval-mae:8.11702
# [1926]	train-mae:11.74329	eval-mae:8.11700
# [1927]	train-mae:11.74243	eval-mae:8.11673
# [1928]	train-mae:11.74122	eval-mae:8.11642
# [1929]	train-mae:11.74031	eval-mae:8.11633
# [1930]	train-mae:11.73802	eval-mae:8.11116
# [1931]	train-mae:11.73720	eval-mae:8.11087
# [1932]	train-mae:11.73615	eval-mae:8.11094
# [1933]	train-mae:11.73530	eval-mae:8.11083
# [1934]	train-mae:11.73411	eval-mae:8.11070
# [1935]	train-mae:11.73315	eval-mae:8.11054
# [1936]	train-mae:11.73198	eval-mae:8.11059
# [1937]	train-mae:11.73094	eval-mae:8.11059
# [1938]	train-mae:11.72957	eval-mae:8.11003
# [1939]	train-mae:11.72859	eval-mae:8.11004
# [1940]	train-mae:11.72680	eval-mae:8.11004
# [1941]	train-mae:11.72597	eval-mae:8.11009
# [1942]	train-mae:11.72459	eval-mae:8.10945
# [1943]	train-mae:11.72344	eval-mae:8.10938
# [1944]	train-mae:11.72252	eval-mae:8.10931
# [1945]	train-mae:11.72158	eval-mae:8.10927
# [1946]	train-mae:11.72073	eval-mae:8.10919
# [1947]	train-mae:11.71966	eval-mae:8.10888
# [1948]	train-mae:11.71880	eval-mae:8.10889
# [1949]	train-mae:11.71737	eval-mae:8.10877
# [1950]	train-mae:11.71656	eval-mae:8.10855
# [1951]	train-mae:11.71583	eval-mae:8.10824
# [1952]	train-mae:11.71478	eval-mae:8.10825
# [1953]	train-mae:11.71386	eval-mae:8.10794
# [1954]	train-mae:11.71259	eval-mae:8.10768
# [1955]	train-mae:11.71127	eval-mae:8.10747
# [1956]	train-mae:11.70982	eval-mae:8.10739
# [1957]	train-mae:11.70842	eval-mae:8.10726
# [1958]	train-mae:11.70713	eval-mae:8.10713
# [1959]	train-mae:11.70605	eval-mae:8.10711
# [1960]	train-mae:11.70507	eval-mae:8.10713
# [1961]	train-mae:11.70409	eval-mae:8.10713
# [1962]	train-mae:11.70267	eval-mae:8.10660
# [1963]	train-mae:11.70110	eval-mae:8.10383
# [1964]	train-mae:11.70018	eval-mae:8.10384
# [1965]	train-mae:11.69895	eval-mae:8.10384
# [1966]	train-mae:11.69797	eval-mae:8.10383
# [1967]	train-mae:11.69665	eval-mae:8.10383
# [1968]	train-mae:11.69563	eval-mae:8.10368
# [1969]	train-mae:11.69454	eval-mae:8.10359
# [1970]	train-mae:11.69370	eval-mae:8.10358
# [1971]	train-mae:11.69266	eval-mae:8.10358
# [1972]	train-mae:11.69207	eval-mae:8.10351
# [1973]	train-mae:11.69120	eval-mae:8.10364
# [1974]	train-mae:11.68981	eval-mae:8.10362
# [1975]	train-mae:11.68874	eval-mae:8.10338
# [1976]	train-mae:11.68776	eval-mae:8.10326
# [1977]	train-mae:11.68686	eval-mae:8.10325
# [1978]	train-mae:11.68591	eval-mae:8.10314
# [1979]	train-mae:11.68504	eval-mae:8.10307
# [1980]	train-mae:11.68444	eval-mae:8.10296
# [1981]	train-mae:11.68320	eval-mae:8.10009
# [1982]	train-mae:11.68221	eval-mae:8.10008
# [1983]	train-mae:11.68142	eval-mae:8.10007
# [1984]	train-mae:11.68037	eval-mae:8.09923
# [1985]	train-mae:11.67942	eval-mae:8.09913
# [1986]	train-mae:11.67834	eval-mae:8.09914
# [1987]	train-mae:11.67749	eval-mae:8.09898
# [1988]	train-mae:11.67654	eval-mae:8.09887
# [1989]	train-mae:11.67572	eval-mae:8.09862
# [1990]	train-mae:11.67455	eval-mae:8.09805
# [1991]	train-mae:11.67386	eval-mae:8.09804
# [1992]	train-mae:11.67248	eval-mae:8.09797
# [1993]	train-mae:11.67168	eval-mae:8.09796
# [1994]	train-mae:11.67064	eval-mae:8.09791
# [1995]	train-mae:11.66931	eval-mae:8.09792
# [1996]	train-mae:11.66835	eval-mae:8.09798
# [1997]	train-mae:11.66765	eval-mae:8.09778
# [1998]	train-mae:11.66649	eval-mae:8.09747
# [1999]	train-mae:11.66526	eval-mae:8.09749

# %% [markdown]
# # Compare

# %%
mae_xgb = mean_absolute_error(y_test, predictions_xgb)
print(f"XGBoost  MAE: {mae_xgb:.4f}")
# Out:
# XGBoost  MAE: 8.0975

# %% [markdown]
# # Visualization

# %%
# 1. Create a DataFrame for XGBoost results
# Ensure 'predictions_xgb' is the output from bst.predict(dtest)
results_xgb = pd.DataFrame({
    'Actual': y_test,
    'XGBoost_Forecast': predictions_xgb
}, index=y_test.index)

# 2. Plotting the 28-day window (2688 rows)
plt.figure(figsize=(15, 7))

# Plot Actual Data
plt.plot(results_xgb['Actual'].iloc[:2688], 
         label='Ground Truth (Actual)', 
         color='blue', 
         alpha=0.6)

# Plot XGBoost Forecast
plt.plot(results_xgb['XGBoost_Forecast'].iloc[:2688], 
         label='XGBoost Forecast', 
         color='green',           # Using Green to distinguish from LightGBM's Red
         linestyle='--', 
         linewidth=1.5)

plt.title('Conductivity Forecast vs Ground Truth (XGBoost - Sept 2025)')
plt.xlabel('Date')
plt.ylabel('Conductivity (μS/cm)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Head to head comparison of forecasts

# %%
plt.figure(figsize=(15, 8))

# Actual
plt.plot(y_test.iloc[:2688], label='Actual', color='black', alpha=0.4, linewidth=2)

# LightGBM (from your previous step)
plt.plot(forecast[:2688], label='LightGBM', color='red', linestyle=':', alpha=0.8)

# XGBoost
plt.plot(predictions_xgb[:2688], label='XGBoost', color='green', linestyle='--', alpha=0.8)

plt.title('Comparison: LightGBM vs XGBoost vs Ground Truth')
plt.legend()
plt.show()
