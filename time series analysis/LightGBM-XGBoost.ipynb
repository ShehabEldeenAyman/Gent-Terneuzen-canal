# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
import requests
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

# %%
VIRTUOSO_URL = "http://localhost:8890/sparql"
GRAPH_URI    = "http://example.com/Gent-Terneuzen"
USERNAME     = "dba"
PASSWORD     = "dba"
AUTH         = (USERNAME, PASSWORD)

# %%
params  = {'graph': GRAPH_URI}
headers = {'Accept': 'text/turtle'}

# %% [markdown]
# # Identifying unique sensors

# %%
sensor_set = set()

sensor_query = f"""
    PREFIX sosa: <http://www.w3.org/ns/sosa/>
    SELECT DISTINCT ?sensor
    WHERE {{
        GRAPH <{GRAPH_URI}> {{
            # ?obs a sosa:Observation ;
                 sosa:madeBySensor ?sensor .
        }}
    }}
    """
res = requests.get(VIRTUOSO_URL, params={'query': sensor_query, 'format': 'application/sparql-results+json'})
if res.status_code != 200:
    print(f"Error: {res.status_code}")
    print("Response:", res.text)
else:
    print("Unique sensors identified successfully!")

data     = res.json()
bindings = data['results']['bindings']
for row in bindings:
    sensor_set.add(row['sensor']['value'])

print(f"Added {len(sensor_set)} unique sensors to the set.")
print("Sensors:", sensor_set)
# Out:
# Unique sensors identified successfully!
# Added 4 unique sensors to the set.
# Sensors: {'http://example.com/waterinfo/289423042', 'http://example.com/waterinfo/289435042', 'http://example.com/waterinfo/289441042', 'http://example.com/waterinfo/289429042'}

# %% [markdown]
# # Reframe the data

# %%
final_df = pd.DataFrame()
print("Fetching and pivoting sensor data...")

for sensor_uri in sensor_set:
    column_name = sensor_uri.split('/')[-1]
    query = f"""
        PREFIX sosa: <http://www.w3.org/ns/sosa/>
        PREFIX ex: <http://example.com/attributes/>
        SELECT ?time ?value ?unixtime
        WHERE {{
            GRAPH <{GRAPH_URI}> {{
                # ?obs a sosa:Observation ;
                    sosa:resultTime ?time ;
                    sosa:hasSimpleResult ?value ;
                    ex:unixTimestamp ?unixtime ;
                    sosa:madeBySensor <{sensor_uri}> .
            }}
        }}
    """
    res = requests.get(VIRTUOSO_URL, params={'query': query, 'format': 'application/sparql-results+json'})
    if res.status_code == 200:
        bindings = res.json()['results']['bindings']
        temp_data = [
            {'time': row['time']['value'], column_name: float(row['value']['value']),
             'unixtime': int(row['unixtime']['value'])}
            for row in bindings
        ]
        temp_df = pd.DataFrame(temp_data)
        if not temp_df.empty:
            temp_df['time'] = pd.to_datetime(temp_df['time'])
            if final_df.empty:
                final_df = temp_df
            else:
                final_df = pd.merge(final_df, temp_df, on=['time', 'unixtime'], how='outer')
            print(f"Added column for sensor: {column_name}")

final_df = final_df.sort_values('time').set_index('time')
print("Finished!")
print(final_df.head())
# Out:
# Fetching and pivoting sensor data...
# Added column for sensor: 289423042
# Added column for sensor: 289435042
# Added column for sensor: 289441042
# Added column for sensor: 289429042
# Finished!
#                            289423042    unixtime  289435042  289441042  \
# time
# 2021-03-03 23:15:00+00:00        NaN  1614813300    3606.54    4797.72
# 2021-03-03 23:30:00+00:00        NaN  1614814200        NaN    4717.80
# 2021-03-03 23:45:00+00:00     902.27  1614815100    3556.45    4745.36
# 2021-03-04 00:00:00+00:00        NaN  1614816000        NaN        NaN
# 2021-03-04 00:15:00+00:00     901.96  1614816900        NaN        NaN
#
#                            289429042
# time
# 2021-03-03 23:15:00+00:00    1605.77
# 2021-03-03 23:30:00+00:00        NaN
# 2021-03-03 23:45:00+00:00    1602.34
# 2021-03-04 00:00:00+00:00    1611.26
# 2021-03-04 00:15:00+00:00    1614.24

# %%
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(12, 10), sharex=True)

sensors = ['289435042', '289423042', '289429042', '289441042']
colors  = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

for i, sensor in enumerate(sensors):
    ax = axes[i]
    ax.plot(final_df.index, final_df[sensor], label=f"Sensor {sensor}", color=colors[i])
    ax.set_ylabel("Value")
    ax.legend(loc='upper right')
    ax.grid(True, alpha=0.3)

plt.suptitle("Sensor Data Analysis", fontsize=16)
plt.xlabel("Time")
plt.xticks(rotation=45)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
data = final_df.copy()
target_sensor = '289441042'

# 1. Time-based features (Seasonality)
data['hour'] = data.index.hour
data['day_of_week'] = data.index.dayofweek
data['month'] = data.index.month


# 2. Lag features for the TARGET (Sensor 4)
    # We look back 15m, 1h, and 24h
for lag in [1, 4, 96,672, 2880]:
    data[f'{target_sensor}_lag_{lag}'] = data[target_sensor].shift(lag)

# 3. Spatial Lag features for NEIGHBORS (Sensors 1, 2, 3)
# These provide "upstream" context
neighbors = [c for c in final_df.columns if c != target_sensor]

for s in neighbors:
        data[f'{s}_lag_1'] = data[s].shift(1)  # What happened 15 mins ago upstream?
        data[f'{s}_lag_4'] = data[s].shift(4)  # What happened 1 hour ago upstream?
        data[f'{s}_lag_672']  = data[s].shift(672)   # 1 week ago upstream
        data[f'{s}_lag_2880'] = data[s].shift(2880)
        data[f'{s}_roc_1']  = data[s].diff(1)   # upstream rate of change
        data[f'{s}_roc_4']  = data[s].diff(4)   # upstream hourly change
        data[f'{s}_roc_672']  = data[s].diff(672)   # upstream weekly change
        data[f'{s}_roc_2880'] = data[s].diff(2880)  # upstream monthly change

# 4. Rolling statistics (Trend)
data['rolling_mean_6h'] = data[target_sensor].shift(1).rolling(window=24).mean()

# In Cell 9, after rolling_mean_6h:

# Rate of change (is the signal rising or falling fast?)
data['roc_1']  = data[target_sensor].diff(1)   # 15-min change
data['roc_4']  = data[target_sensor].diff(4)   # 1-hour change
data['roc_96'] = data[target_sensor].diff(96)  # 24-hour change

# Volatility (is the signal stable or jumping around?)
data['rolling_std_6h']  = data[target_sensor].shift(1).rolling(window=24).std()
data['rolling_std_24h'] = data[target_sensor].shift(1).rolling(window=96).std()

# Rolling min/max (captures the range of recent behaviour)
data['rolling_max_24h'] = data[target_sensor].shift(1).rolling(window=96).max()
data['rolling_min_24h'] = data[target_sensor].shift(1).rolling(window=96).min()


data.dropna(inplace=True)
df_featured = data.copy()
print(f"df_featured shape: {df_featured.shape}")
print(f"Date range: {df_featured.index.min()} → {df_featured.index.max()}")
# Out:
# df_featured shape: (75402, 53)
# Date range: 2023-02-06 14:00:00+00:00 → 2025-10-07 07:30:00+00:00

# %% [markdown]
# # Data preparation

# %%
# Split based on your specific dates
train_data = df_featured[:'2025-07-31'] # all data up to July 2025
test_data = df_featured['2025-07-01':'2025-07-30'] # ground truth month



X_train = train_data.drop(columns=sensors)  # Drop original sensor columns
y_train = train_data[target_sensor]

X_test = test_data.drop(columns=sensors)
y_test = test_data[target_sensor]

# Does the data contain high conductivity events? 
print("Train conductivity range:", y_train.min(), "→", y_train.max())
print("Test  conductivity range:", y_test.min(),  "→", y_test.max())
# Out:
# Train conductivity range: 226.79 → 16851.66
# Test  conductivity range: 6074.92 → 7693.67

# %%
# Sanity check
# #print("Training data shape:", X_train.shape)
# print("Testing data shape:", X_test.shape)
# #print(X_train.head())
# print(X_test.head())

# %% [markdown]
# # Actual training

# %%
model = lgb.LGBMRegressor(
    n_estimators=5000,      # Increased: More trees for better learning
    learning_rate=0.01,     # Decreased: Slower, more precise learning
    num_leaves=128,         # Increased: Allows for more complex patterns
    max_depth=12,           # Limited: Prevents the trees from growing too deep
    min_data_in_leaf=50,   # Regularization: Prevents overfitting to noise (lower = more sensitive)
    feature_fraction=0.8,   # Generalization: Don't rely on all sensors at once
    n_jobs=-1,
    subsample=0.8,          # ADD: row subsampling for better generalisation
    reg_alpha=0.1,          # ADD: L1 regularisation
    reg_lambda=0.1,         # ADD: L2 regularisation
)

# Use early stopping to find the perfect n_estimators automatically
model.fit(
    X_train, y_train,
    eval_set=[(X_test, y_test)],
    eval_metric='rmse',
    callbacks=[lgb.early_stopping(stopping_rounds=100)] 
)
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008343 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10783
# [LightGBM] [Info] Number of data points in the train set: 69041, number of used features: 47
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Info] Start training from score 6231.913078
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [5000]	valid_0's rmse: 9.52267	valid_0's l2: 90.6813
# LGBMRegressor(feature_fraction=0.8, learning_rate=0.01, max_depth=12,
#               min_data_in_leaf=50, n_estimators=5000, n_jobs=-1, num_leaves=128,
#               reg_alpha=0.1, reg_lambda=0.1, subsample=0.8)

# %% [markdown]
# # Forecast and Compare

# %%
forecast = model.predict(X_test)

mae = mean_absolute_error(y_test, forecast)
print(f"September 2025 Forecast MAE: {mae:.4f} units of conductivity")
# Out:
# [LightGBM] [Warning] min_data_in_leaf is set=50, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=50
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# September 2025 Forecast MAE: 7.2644 units of conductivity

# %% [markdown]
# # Bias check

# %%
error = y_test - forecast
print(f"Mean Error (Bias): {error.mean()}")

# positive bias means we are underpredicting on average, negative bias means we are overpredicting on average.
# Out:
# Mean Error (Bias): 0.06057593035504122

# %% [markdown]
# # Visualizing truth vs prediction

# %%
# 1. Create a DataFrame for easy plotting
results = pd.DataFrame({
    'Actual': y_test,
    'Forecast': forecast
}, index=y_test.index)

# 2. Plotting a 7-day window to see the detail
plt.figure(figsize=(15, 7))
plt.plot(results['Actual'].iloc[:2688], label='Ground Truth (Actual)', color='blue', alpha=0.7)
# 672 rows = 7 days * 24 hours * 4 readings/hour
plt.plot(results['Forecast'].iloc[:2688], label='LightGBM Forecast', color='red', linestyle='--')

plt.title('Conductivity Forecast vs Ground Truth (Month of September 2025)')
plt.xlabel('Date')
plt.ylabel('Conductivity (μS/cm)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## The model is really good in predicting a week in the future. Any more than that and it falls of quite quickly

# %% [markdown]
# # XGBoost

# %%
# 1. Convert your data into XGBoost's optimized format (DMatrix)
# Note: You use the same X_train, y_train we created for LightGBM
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
params = {
    'objective': 'reg:squarederror', # We are predicting a number (conductivity)
    'max_depth': 6,                 # Depth of trees
    'eta': 0.01,                    # Learning rate (same as 'learning_rate')
    'subsample': 0.8,               # Use 80% of data to grow each tree (prevents overfitting)
    'colsample_bytree': 0.8,        # Use 80% of sensors for each tree
    'eval_metric': 'mae'
}

# We use 'evallist' to watch the error in real-time
evallist = [(dtrain, 'train'), (dtest, 'eval')]
num_round = 2000

bst = xgb.train(params, dtrain, num_round, evallist, early_stopping_rounds=50)

# 4. Forecast 
predictions_xgb = bst.predict(dtest)
# Out:
# [0]	train-mae:2711.47670	eval-mae:737.40756
# [1]	train-mae:2684.41138	eval-mae:729.97750
# [2]	train-mae:2657.61953	eval-mae:722.61716
# [3]	train-mae:2631.10090	eval-mae:715.33575
# [4]	train-mae:2604.84195	eval-mae:708.06743
# [5]	train-mae:2578.85027	eval-mae:700.91154
# [6]	train-mae:2553.11468	eval-mae:693.80918
# [7]	train-mae:2527.63710	eval-mae:686.80386
# [8]	train-mae:2502.41575	eval-mae:679.87559
# C:\Users\AYMANS\AppData\Roaming\Python\Python313\site-packages\xgboost\core.py:748: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [9]	train-mae:2477.45571	eval-mae:673.13426
# [10]	train-mae:2452.74014	eval-mae:666.32053
# [11]	train-mae:2428.27121	eval-mae:659.61158
# [12]	train-mae:2404.04112	eval-mae:652.95517
# [13]	train-mae:2380.05948	eval-mae:646.37796
# [14]	train-mae:2356.31727	eval-mae:639.84808
# [15]	train-mae:2332.80790	eval-mae:633.44714
# [16]	train-mae:2309.53594	eval-mae:627.15559
# [17]	train-mae:2286.49736	eval-mae:620.81660
# [18]	train-mae:2263.68191	eval-mae:614.54357
# [19]	train-mae:2241.10160	eval-mae:608.31612
# [20]	train-mae:2218.80161	eval-mae:602.26735
# [21]	train-mae:2196.66483	eval-mae:596.18148
# [22]	train-mae:2174.75136	eval-mae:590.26392
# [23]	train-mae:2153.05962	eval-mae:584.28855
# [24]	train-mae:2131.58850	eval-mae:578.38205
# [25]	train-mae:2110.42108	eval-mae:572.85420
# [26]	train-mae:2089.37410	eval-mae:567.06439
# [27]	train-mae:2068.53158	eval-mae:561.33122
# [28]	train-mae:2047.90033	eval-mae:555.64633
# [29]	train-mae:2027.48683	eval-mae:550.02850
# [30]	train-mae:2007.31376	eval-mae:544.50837
# [31]	train-mae:1987.29669	eval-mae:539.01464
# [32]	train-mae:1967.48147	eval-mae:533.58862
# [33]	train-mae:1947.86448	eval-mae:528.25205
# [34]	train-mae:1928.45146	eval-mae:522.98998
# [35]	train-mae:1909.22271	eval-mae:517.73603
# [36]	train-mae:1890.18995	eval-mae:512.61477
# [37]	train-mae:1871.34681	eval-mae:507.42468
# [38]	train-mae:1852.69695	eval-mae:502.36373
# [39]	train-mae:1834.23181	eval-mae:497.37827
# [40]	train-mae:1815.95254	eval-mae:492.42891
# [41]	train-mae:1797.84545	eval-mae:487.46278
# [42]	train-mae:1779.93035	eval-mae:482.61022
# [43]	train-mae:1762.19163	eval-mae:477.80218
# [44]	train-mae:1744.62222	eval-mae:472.98205
# [45]	train-mae:1727.24094	eval-mae:468.32495
# [46]	train-mae:1710.02331	eval-mae:463.63131
# [47]	train-mae:1692.97800	eval-mae:459.03820
# [48]	train-mae:1676.10512	eval-mae:454.40414
# [49]	train-mae:1659.40810	eval-mae:449.91202
# [50]	train-mae:1642.86943	eval-mae:445.38078
# [51]	train-mae:1626.49447	eval-mae:440.95100
# [52]	train-mae:1610.28378	eval-mae:436.53432
# [53]	train-mae:1594.23525	eval-mae:432.14516
# [54]	train-mae:1578.41433	eval-mae:427.90962
# [55]	train-mae:1562.68158	eval-mae:423.68921
# [56]	train-mae:1547.10521	eval-mae:419.50092
# [57]	train-mae:1531.77484	eval-mae:415.37413
# [58]	train-mae:1516.51608	eval-mae:411.28226
# [59]	train-mae:1501.41268	eval-mae:407.22341
# [60]	train-mae:1486.45375	eval-mae:403.22554
# [61]	train-mae:1471.64777	eval-mae:399.16944
# [62]	train-mae:1456.99069	eval-mae:395.11708
# [63]	train-mae:1442.47232	eval-mae:391.20052
# [64]	train-mae:1428.10440	eval-mae:387.37005
# [65]	train-mae:1413.92944	eval-mae:383.53902
# [66]	train-mae:1399.84637	eval-mae:379.70211
# [67]	train-mae:1385.89884	eval-mae:375.92684
# [68]	train-mae:1372.15620	eval-mae:372.19489
# [69]	train-mae:1358.48820	eval-mae:368.43603
# [70]	train-mae:1344.96144	eval-mae:364.76648
# [71]	train-mae:1331.56705	eval-mae:361.06085
# [72]	train-mae:1318.30503	eval-mae:357.44051
# [73]	train-mae:1305.21945	eval-mae:353.90409
# [74]	train-mae:1292.22082	eval-mae:350.38004
# [75]	train-mae:1279.34922	eval-mae:346.91153
# [76]	train-mae:1266.61301	eval-mae:343.47440
# [77]	train-mae:1254.05340	eval-mae:340.16077
# [78]	train-mae:1241.57057	eval-mae:336.80162
# [79]	train-mae:1229.21062	eval-mae:333.42320
# [80]	train-mae:1217.00130	eval-mae:330.15834
# [81]	train-mae:1204.93264	eval-mae:327.05098
# [82]	train-mae:1192.93548	eval-mae:323.83548
# [83]	train-mae:1181.05955	eval-mae:320.65778
# [84]	train-mae:1169.30304	eval-mae:317.44930
# [85]	train-mae:1157.66605	eval-mae:314.29289
# [86]	train-mae:1146.14310	eval-mae:311.19868
# [87]	train-mae:1134.73744	eval-mae:308.07502
# [88]	train-mae:1123.47730	eval-mae:305.07533
# [89]	train-mae:1112.32873	eval-mae:302.06736
# [90]	train-mae:1101.25966	eval-mae:299.03518
# [91]	train-mae:1090.32938	eval-mae:296.07018
# [92]	train-mae:1079.48197	eval-mae:293.16324
# [93]	train-mae:1068.73938	eval-mae:290.21489
# [94]	train-mae:1058.09964	eval-mae:287.25085
# [95]	train-mae:1047.57311	eval-mae:284.44023
# [96]	train-mae:1037.15093	eval-mae:281.64414
# [97]	train-mae:1026.86243	eval-mae:278.84738
# [98]	train-mae:1016.64302	eval-mae:276.00814
# [99]	train-mae:1006.52960	eval-mae:273.23252
# [100]	train-mae:996.51687	eval-mae:270.48755
# [101]	train-mae:986.60340	eval-mae:267.79338
# [102]	train-mae:976.78850	eval-mae:265.14223
# [103]	train-mae:967.11995	eval-mae:262.65039
# [104]	train-mae:957.50293	eval-mae:260.05632
# [105]	train-mae:947.98179	eval-mae:257.45749
# [106]	train-mae:938.55790	eval-mae:254.87719
# [107]	train-mae:929.26261	eval-mae:252.42648
# [108]	train-mae:920.02221	eval-mae:249.90607
# [109]	train-mae:910.87550	eval-mae:247.44692
# [110]	train-mae:901.82889	eval-mae:245.03236
# [111]	train-mae:892.86307	eval-mae:242.63282
# [112]	train-mae:883.98735	eval-mae:240.20238
# [113]	train-mae:875.20128	eval-mae:237.73944
# [114]	train-mae:866.50458	eval-mae:235.40479
# [115]	train-mae:857.89439	eval-mae:233.07004
# [116]	train-mae:849.37139	eval-mae:230.74253
# [117]	train-mae:840.92682	eval-mae:228.43040
# [118]	train-mae:832.59394	eval-mae:226.16967
# [119]	train-mae:824.32776	eval-mae:223.90233
# [120]	train-mae:816.14093	eval-mae:221.67568
# [121]	train-mae:808.03214	eval-mae:219.41597
# [122]	train-mae:799.99844	eval-mae:217.22510
# [123]	train-mae:792.06346	eval-mae:215.11181
# [124]	train-mae:784.20244	eval-mae:213.00474
# [125]	train-mae:776.41133	eval-mae:210.79006
# [126]	train-mae:768.70320	eval-mae:208.69079
# [127]	train-mae:761.07181	eval-mae:206.60501
# [128]	train-mae:753.53246	eval-mae:204.58983
# [129]	train-mae:746.06725	eval-mae:202.63010
# [130]	train-mae:738.66314	eval-mae:200.60109
# [131]	train-mae:731.33307	eval-mae:198.59146
# [132]	train-mae:724.06809	eval-mae:196.61068
# [133]	train-mae:716.88769	eval-mae:194.65606
# [134]	train-mae:709.79301	eval-mae:192.78454
# [135]	train-mae:702.78057	eval-mae:190.90098
# [136]	train-mae:695.80441	eval-mae:189.02943
# [137]	train-mae:688.91966	eval-mae:187.13119
# [138]	train-mae:682.08705	eval-mae:185.29017
# [139]	train-mae:675.32178	eval-mae:183.42588
# [140]	train-mae:668.61505	eval-mae:181.55049
# [141]	train-mae:661.98930	eval-mae:179.59814
# [142]	train-mae:655.42315	eval-mae:177.81438
# [143]	train-mae:648.93321	eval-mae:176.02079
# [144]	train-mae:642.49757	eval-mae:174.27756
# [145]	train-mae:636.16171	eval-mae:172.65533
# [146]	train-mae:629.84669	eval-mae:170.83060
# [147]	train-mae:623.60645	eval-mae:169.14090
# [148]	train-mae:617.42530	eval-mae:167.36259
# [149]	train-mae:611.29684	eval-mae:165.55938
# [150]	train-mae:605.25598	eval-mae:163.93865
# [151]	train-mae:599.26083	eval-mae:162.35794
# [152]	train-mae:593.32210	eval-mae:160.70521
# [153]	train-mae:587.44385	eval-mae:159.09036
# [154]	train-mae:581.62622	eval-mae:157.50541
# [155]	train-mae:575.87014	eval-mae:155.83633
# [156]	train-mae:570.16008	eval-mae:154.29637
# [157]	train-mae:564.50967	eval-mae:152.79336
# [158]	train-mae:558.92268	eval-mae:151.27155
# [159]	train-mae:553.37692	eval-mae:149.67178
# [160]	train-mae:547.89147	eval-mae:148.10340
# [161]	train-mae:542.47040	eval-mae:146.67623
# [162]	train-mae:537.09672	eval-mae:145.15378
# [163]	train-mae:531.78074	eval-mae:143.75451
# [164]	train-mae:526.53291	eval-mae:142.36205
# [165]	train-mae:521.32153	eval-mae:140.91918
# [166]	train-mae:516.16360	eval-mae:139.55988
# [167]	train-mae:511.05593	eval-mae:138.29690
# [168]	train-mae:506.00001	eval-mae:136.98766
# [169]	train-mae:500.98746	eval-mae:135.59862
# [170]	train-mae:496.02389	eval-mae:134.18896
# [171]	train-mae:491.11937	eval-mae:132.89756
# [172]	train-mae:486.26441	eval-mae:131.57789
# [173]	train-mae:481.45110	eval-mae:130.23302
# [174]	train-mae:476.68402	eval-mae:128.87538
# [175]	train-mae:471.97386	eval-mae:127.53694
# [176]	train-mae:467.31049	eval-mae:126.22474
# [177]	train-mae:462.68604	eval-mae:124.95624
# [178]	train-mae:458.11965	eval-mae:123.66423
# [179]	train-mae:453.58005	eval-mae:122.54025
# [180]	train-mae:449.10082	eval-mae:121.38572
# [181]	train-mae:444.66821	eval-mae:120.23636
# [182]	train-mae:440.26408	eval-mae:118.96299
# [183]	train-mae:435.90098	eval-mae:117.76207
# [184]	train-mae:431.58373	eval-mae:116.52485
# [185]	train-mae:427.32193	eval-mae:115.40110
# [186]	train-mae:423.09149	eval-mae:114.35772
# [187]	train-mae:418.90308	eval-mae:113.19565
# [188]	train-mae:414.77180	eval-mae:112.04496
# [189]	train-mae:410.66836	eval-mae:111.02988
# [190]	train-mae:406.60520	eval-mae:109.91356
# [191]	train-mae:402.57665	eval-mae:108.78841
# [192]	train-mae:398.59452	eval-mae:107.77883
# [193]	train-mae:394.66111	eval-mae:106.77090
# [194]	train-mae:390.75564	eval-mae:105.68011
# [195]	train-mae:386.89580	eval-mae:104.68725
# [196]	train-mae:383.08134	eval-mae:103.62711
# [197]	train-mae:379.29721	eval-mae:102.63544
# [198]	train-mae:375.56289	eval-mae:101.63214
# [199]	train-mae:371.85331	eval-mae:100.68164
# [200]	train-mae:368.18122	eval-mae:99.75717
# [201]	train-mae:364.53851	eval-mae:98.80288
# [202]	train-mae:360.94614	eval-mae:97.89352
# [203]	train-mae:357.37792	eval-mae:96.85834
# [204]	train-mae:353.85329	eval-mae:95.94917
# [205]	train-mae:350.35411	eval-mae:94.92340
# [206]	train-mae:346.88956	eval-mae:93.98419
# [207]	train-mae:343.45722	eval-mae:93.07774
# [208]	train-mae:340.09008	eval-mae:92.23819
# [209]	train-mae:336.72716	eval-mae:91.31207
# [210]	train-mae:333.40369	eval-mae:90.45592
# [211]	train-mae:330.12199	eval-mae:89.62233
# [212]	train-mae:326.86553	eval-mae:88.73018
# [213]	train-mae:323.63416	eval-mae:87.79113
# [214]	train-mae:320.43642	eval-mae:86.87724
# [215]	train-mae:317.30823	eval-mae:86.02124
# [216]	train-mae:314.17700	eval-mae:85.23693
# [217]	train-mae:311.08721	eval-mae:84.44053
# [218]	train-mae:308.01374	eval-mae:83.58617
# [219]	train-mae:304.97413	eval-mae:82.78014
# [220]	train-mae:301.96778	eval-mae:82.01127
# [221]	train-mae:298.98896	eval-mae:81.24085
# [222]	train-mae:296.03728	eval-mae:80.48149
# [223]	train-mae:293.12009	eval-mae:79.75459
# [224]	train-mae:290.22410	eval-mae:78.94897
# [225]	train-mae:287.37522	eval-mae:78.24212
# [226]	train-mae:284.53994	eval-mae:77.47843
# [227]	train-mae:281.73267	eval-mae:76.71749
# [228]	train-mae:278.96519	eval-mae:76.02659
# [229]	train-mae:276.23262	eval-mae:75.29134
# [230]	train-mae:273.50933	eval-mae:74.54997
# [231]	train-mae:270.80833	eval-mae:73.75594
# [232]	train-mae:268.14696	eval-mae:73.07575
# [233]	train-mae:265.49894	eval-mae:72.31213
# [234]	train-mae:262.90802	eval-mae:71.72819
# [235]	train-mae:260.31316	eval-mae:71.02826
# [236]	train-mae:257.76468	eval-mae:70.39556
# [237]	train-mae:255.22915	eval-mae:69.77400
# [238]	train-mae:252.71410	eval-mae:69.14856
# [239]	train-mae:250.23698	eval-mae:68.52393
# [240]	train-mae:247.77101	eval-mae:67.87458
# [241]	train-mae:245.32878	eval-mae:67.17211
# [242]	train-mae:242.92134	eval-mae:66.49344
# [243]	train-mae:240.54840	eval-mae:65.93220
# [244]	train-mae:238.18210	eval-mae:65.35923
# [245]	train-mae:235.83815	eval-mae:64.71083
# [246]	train-mae:233.52920	eval-mae:64.11885
# [247]	train-mae:231.24542	eval-mae:63.55707
# [248]	train-mae:228.98396	eval-mae:62.96663
# [249]	train-mae:226.74045	eval-mae:62.43198
# [250]	train-mae:224.51700	eval-mae:61.84712
# [251]	train-mae:222.31176	eval-mae:61.24328
# [252]	train-mae:220.12720	eval-mae:60.64704
# [253]	train-mae:217.96214	eval-mae:60.03655
# [254]	train-mae:215.84191	eval-mae:59.49389
# [255]	train-mae:213.73642	eval-mae:58.97772
# [256]	train-mae:211.65033	eval-mae:58.49784
# [257]	train-mae:209.59350	eval-mae:58.03471
# [258]	train-mae:207.54951	eval-mae:57.54027
# [259]	train-mae:205.52546	eval-mae:57.03579
# [260]	train-mae:203.50606	eval-mae:56.49033
# [261]	train-mae:201.50840	eval-mae:55.98979
# [262]	train-mae:199.55064	eval-mae:55.53162
# [263]	train-mae:197.59902	eval-mae:55.03145
# [264]	train-mae:195.66480	eval-mae:54.51272
# [265]	train-mae:193.74886	eval-mae:54.01503
# [266]	train-mae:191.85549	eval-mae:53.48713
# [267]	train-mae:189.97710	eval-mae:52.98988
# [268]	train-mae:188.11530	eval-mae:52.49570
# [269]	train-mae:186.28222	eval-mae:52.02066
# [270]	train-mae:184.45551	eval-mae:51.53227
# [271]	train-mae:182.64543	eval-mae:51.00172
# [272]	train-mae:180.86215	eval-mae:50.55199
# [273]	train-mae:179.09137	eval-mae:50.11532
# [274]	train-mae:177.34270	eval-mae:49.67907
# [275]	train-mae:175.61768	eval-mae:49.27532
# [276]	train-mae:173.89841	eval-mae:48.78650
# [277]	train-mae:172.19969	eval-mae:48.35936
# [278]	train-mae:170.52656	eval-mae:47.93657
# [279]	train-mae:168.85702	eval-mae:47.46698
# [280]	train-mae:167.20584	eval-mae:47.01062
# [281]	train-mae:165.56775	eval-mae:46.56137
# [282]	train-mae:163.96689	eval-mae:46.21371
# [283]	train-mae:162.37374	eval-mae:45.79318
# [284]	train-mae:160.79263	eval-mae:45.41878
# [285]	train-mae:159.22353	eval-mae:45.04254
# [286]	train-mae:157.67788	eval-mae:44.66667
# [287]	train-mae:156.14168	eval-mae:44.27446
# [288]	train-mae:154.62813	eval-mae:43.87313
# [289]	train-mae:153.13904	eval-mae:43.51574
# [290]	train-mae:151.64657	eval-mae:43.12452
# [291]	train-mae:150.17074	eval-mae:42.77915
# [292]	train-mae:148.70543	eval-mae:42.41418
# [293]	train-mae:147.25461	eval-mae:42.02422
# [294]	train-mae:145.82108	eval-mae:41.64172
# [295]	train-mae:144.40915	eval-mae:41.26796
# [296]	train-mae:143.01258	eval-mae:40.93519
# [297]	train-mae:141.63662	eval-mae:40.58589
# [298]	train-mae:140.25733	eval-mae:40.22161
# [299]	train-mae:138.89100	eval-mae:39.85995
# [300]	train-mae:137.54037	eval-mae:39.52133
# [301]	train-mae:136.20373	eval-mae:39.17782
# [302]	train-mae:134.88831	eval-mae:38.80796
# [303]	train-mae:133.57821	eval-mae:38.51301
# [304]	train-mae:132.28068	eval-mae:38.17705
# [305]	train-mae:130.99687	eval-mae:37.85447
# [306]	train-mae:129.72779	eval-mae:37.56224
# [307]	train-mae:128.46985	eval-mae:37.26285
# [308]	train-mae:127.22614	eval-mae:36.95575
# [309]	train-mae:126.00113	eval-mae:36.66153
# [310]	train-mae:124.77748	eval-mae:36.34892
# [311]	train-mae:123.57189	eval-mae:36.05758
# [312]	train-mae:122.37612	eval-mae:35.78024
# [313]	train-mae:121.19067	eval-mae:35.48008
# [314]	train-mae:120.01769	eval-mae:35.19078
# [315]	train-mae:118.86163	eval-mae:34.88337
# [316]	train-mae:117.71841	eval-mae:34.60665
# [317]	train-mae:116.57704	eval-mae:34.30560
# [318]	train-mae:115.45946	eval-mae:34.01547
# [319]	train-mae:114.36333	eval-mae:33.80207
# [320]	train-mae:113.25792	eval-mae:33.49271
# [321]	train-mae:112.16671	eval-mae:33.25100
# [322]	train-mae:111.08576	eval-mae:32.98002
# [323]	train-mae:110.01507	eval-mae:32.72620
# [324]	train-mae:108.95245	eval-mae:32.44896
# [325]	train-mae:107.90359	eval-mae:32.17519
# [326]	train-mae:106.87249	eval-mae:31.93291
# [327]	train-mae:105.84746	eval-mae:31.64622
# [328]	train-mae:104.82736	eval-mae:31.38072
# [329]	train-mae:103.81805	eval-mae:31.07931
# [330]	train-mae:102.82275	eval-mae:30.85573
# [331]	train-mae:101.83547	eval-mae:30.60791
# [332]	train-mae:100.86463	eval-mae:30.40790
# [333]	train-mae:99.89653	eval-mae:30.18368
# [334]	train-mae:98.94547	eval-mae:29.96861
# [335]	train-mae:97.99550	eval-mae:29.71946
# [336]	train-mae:97.07189	eval-mae:29.54702
# [337]	train-mae:96.15054	eval-mae:29.35937
# [338]	train-mae:95.23001	eval-mae:29.13406
# [339]	train-mae:94.32710	eval-mae:28.91761
# [340]	train-mae:93.42367	eval-mae:28.69472
# [341]	train-mae:92.52895	eval-mae:28.44211
# [342]	train-mae:91.65206	eval-mae:28.25563
# [343]	train-mae:90.77594	eval-mae:28.04778
# [344]	train-mae:89.90780	eval-mae:27.83907
# [345]	train-mae:89.04950	eval-mae:27.64876
# [346]	train-mae:88.19993	eval-mae:27.46175
# [347]	train-mae:87.36612	eval-mae:27.29108
# [348]	train-mae:86.53167	eval-mae:27.08644
# [349]	train-mae:85.70638	eval-mae:26.84144
# [350]	train-mae:84.88810	eval-mae:26.65262
# [351]	train-mae:84.08306	eval-mae:26.45248
# [352]	train-mae:83.28460	eval-mae:26.27748
# [353]	train-mae:82.49937	eval-mae:26.06725
# [354]	train-mae:81.71722	eval-mae:25.84918
# [355]	train-mae:80.93889	eval-mae:25.64316
# [356]	train-mae:80.17124	eval-mae:25.43414
# [357]	train-mae:79.41896	eval-mae:25.26326
# [358]	train-mae:78.66659	eval-mae:25.09237
# [359]	train-mae:77.92210	eval-mae:24.93380
# [360]	train-mae:77.18258	eval-mae:24.71176
# [361]	train-mae:76.45009	eval-mae:24.50178
# [362]	train-mae:75.73185	eval-mae:24.34479
# [363]	train-mae:75.02546	eval-mae:24.18520
# [364]	train-mae:74.31848	eval-mae:23.96717
# [365]	train-mae:73.61845	eval-mae:23.77539
# [366]	train-mae:72.92338	eval-mae:23.61248
# [367]	train-mae:72.23429	eval-mae:23.43093
# [368]	train-mae:71.55288	eval-mae:23.25441
# [369]	train-mae:70.89119	eval-mae:23.12451
# [370]	train-mae:70.22630	eval-mae:22.97975
# [371]	train-mae:69.57764	eval-mae:22.85739
# [372]	train-mae:68.92349	eval-mae:22.66544
# [373]	train-mae:68.28633	eval-mae:22.48272
# [374]	train-mae:67.64780	eval-mae:22.33992
# [375]	train-mae:67.01340	eval-mae:22.17348
# [376]	train-mae:66.38701	eval-mae:22.01430
# [377]	train-mae:65.76576	eval-mae:21.87045
# [378]	train-mae:65.15574	eval-mae:21.73209
# [379]	train-mae:64.54798	eval-mae:21.55571
# [380]	train-mae:63.94877	eval-mae:21.43203
# [381]	train-mae:63.35370	eval-mae:21.27602
# [382]	train-mae:62.76346	eval-mae:21.14607
# [383]	train-mae:62.18725	eval-mae:21.02101
# [384]	train-mae:61.61224	eval-mae:20.90148
# [385]	train-mae:61.04302	eval-mae:20.74565
# [386]	train-mae:60.47746	eval-mae:20.59527
# [387]	train-mae:59.91830	eval-mae:20.43333
# [388]	train-mae:59.36697	eval-mae:20.27760
# [389]	train-mae:58.81702	eval-mae:20.13503
# [390]	train-mae:58.27607	eval-mae:20.00458
# [391]	train-mae:57.74533	eval-mae:19.87264
# [392]	train-mae:57.21366	eval-mae:19.75907
# [393]	train-mae:56.69039	eval-mae:19.64320
# [394]	train-mae:56.17139	eval-mae:19.50057
# [395]	train-mae:55.65661	eval-mae:19.36681
# [396]	train-mae:55.14717	eval-mae:19.22694
# [397]	train-mae:54.64145	eval-mae:19.09174
# [398]	train-mae:54.14256	eval-mae:18.98252
# [399]	train-mae:53.65164	eval-mae:18.88153
# [400]	train-mae:53.17097	eval-mae:18.76236
# [401]	train-mae:52.69153	eval-mae:18.65661
# [402]	train-mae:52.22476	eval-mae:18.56027
# [403]	train-mae:51.75160	eval-mae:18.44557
# [404]	train-mae:51.28323	eval-mae:18.33575
# [405]	train-mae:50.82129	eval-mae:18.20510
# [406]	train-mae:50.36382	eval-mae:18.09405
# [407]	train-mae:49.90907	eval-mae:17.99212
# [408]	train-mae:49.45915	eval-mae:17.87484
# [409]	train-mae:49.01301	eval-mae:17.75027
# [410]	train-mae:48.57634	eval-mae:17.66619
# [411]	train-mae:48.14377	eval-mae:17.56038
# [412]	train-mae:47.71522	eval-mae:17.45178
# [413]	train-mae:47.29065	eval-mae:17.34314
# [414]	train-mae:46.87185	eval-mae:17.23121
# [415]	train-mae:46.45625	eval-mae:17.12232
# [416]	train-mae:46.04428	eval-mae:17.02227
# [417]	train-mae:45.64001	eval-mae:16.92803
# [418]	train-mae:45.23779	eval-mae:16.82589
# [419]	train-mae:44.83881	eval-mae:16.74367
# [420]	train-mae:44.44851	eval-mae:16.67553
# [421]	train-mae:44.06007	eval-mae:16.57918
# [422]	train-mae:43.67974	eval-mae:16.50865
# [423]	train-mae:43.30360	eval-mae:16.42917
# [424]	train-mae:42.92546	eval-mae:16.33073
# [425]	train-mae:42.55719	eval-mae:16.25436
# [426]	train-mae:42.19365	eval-mae:16.16042
# [427]	train-mae:41.82857	eval-mae:16.06235
# [428]	train-mae:41.46850	eval-mae:15.97580
# [429]	train-mae:41.11135	eval-mae:15.88704
# [430]	train-mae:40.76009	eval-mae:15.79589
# [431]	train-mae:40.41320	eval-mae:15.71215
# [432]	train-mae:40.06937	eval-mae:15.63659
# [433]	train-mae:39.72634	eval-mae:15.55322
# [434]	train-mae:39.38879	eval-mae:15.46577
# [435]	train-mae:39.05345	eval-mae:15.38036
# [436]	train-mae:38.72879	eval-mae:15.30244
# [437]	train-mae:38.40422	eval-mae:15.22144
# [438]	train-mae:38.08721	eval-mae:15.14305
# [439]	train-mae:37.76944	eval-mae:15.07152
# [440]	train-mae:37.45332	eval-mae:14.99389
# [441]	train-mae:37.14243	eval-mae:14.92967
# [442]	train-mae:36.84557	eval-mae:14.89638
# [443]	train-mae:36.54180	eval-mae:14.82734
# [444]	train-mae:36.24165	eval-mae:14.75409
# [445]	train-mae:35.94419	eval-mae:14.66987
# [446]	train-mae:35.65125	eval-mae:14.60641
# [447]	train-mae:35.36115	eval-mae:14.53726
# [448]	train-mae:35.07544	eval-mae:14.47804
# [449]	train-mae:34.79008	eval-mae:14.40813
# [450]	train-mae:34.51377	eval-mae:14.35561
# [451]	train-mae:34.23714	eval-mae:14.28570
# [452]	train-mae:33.96609	eval-mae:14.24217
# [453]	train-mae:33.69550	eval-mae:14.17934
# [454]	train-mae:33.42705	eval-mae:14.11202
# [455]	train-mae:33.16017	eval-mae:14.04325
# [456]	train-mae:32.89814	eval-mae:13.97995
# [457]	train-mae:32.64309	eval-mae:13.93934
# [458]	train-mae:32.39127	eval-mae:13.88003
# [459]	train-mae:32.14038	eval-mae:13.81813
# [460]	train-mae:31.88870	eval-mae:13.75600
# [461]	train-mae:31.64468	eval-mae:13.70898
# [462]	train-mae:31.40142	eval-mae:13.64841
# [463]	train-mae:31.16040	eval-mae:13.59651
# [464]	train-mae:30.92433	eval-mae:13.54427
# [465]	train-mae:30.68846	eval-mae:13.47964
# [466]	train-mae:30.45739	eval-mae:13.41597
# [467]	train-mae:30.22851	eval-mae:13.36052
# [468]	train-mae:30.00359	eval-mae:13.31663
# [469]	train-mae:29.78126	eval-mae:13.26820
# [470]	train-mae:29.56249	eval-mae:13.20307
# [471]	train-mae:29.34433	eval-mae:13.14680
# [472]	train-mae:29.12691	eval-mae:13.08881
# [473]	train-mae:28.91243	eval-mae:13.03691
# [474]	train-mae:28.71133	eval-mae:13.00336
# [475]	train-mae:28.50288	eval-mae:12.94927
# [476]	train-mae:28.29837	eval-mae:12.89269
# [477]	train-mae:28.09798	eval-mae:12.85153
# [478]	train-mae:27.89689	eval-mae:12.81721
# [479]	train-mae:27.70048	eval-mae:12.76718
# [480]	train-mae:27.50805	eval-mae:12.72525
# [481]	train-mae:27.31898	eval-mae:12.68313
# [482]	train-mae:27.12831	eval-mae:12.63661
# [483]	train-mae:26.94329	eval-mae:12.60261
# [484]	train-mae:26.75749	eval-mae:12.55880
# [485]	train-mae:26.57494	eval-mae:12.51126
# [486]	train-mae:26.39610	eval-mae:12.47382
# [487]	train-mae:26.21908	eval-mae:12.42478
# [488]	train-mae:26.05334	eval-mae:12.41070
# [489]	train-mae:25.87791	eval-mae:12.36794
# [490]	train-mae:25.70719	eval-mae:12.32880
# [491]	train-mae:25.53662	eval-mae:12.28666
# [492]	train-mae:25.36730	eval-mae:12.24646
# [493]	train-mae:25.20211	eval-mae:12.20147
# [494]	train-mae:25.03881	eval-mae:12.15550
# [495]	train-mae:24.87990	eval-mae:12.11362
# [496]	train-mae:24.72404	eval-mae:12.07687
# [497]	train-mae:24.56801	eval-mae:12.03194
# [498]	train-mae:24.41311	eval-mae:11.99034
# [499]	train-mae:24.26124	eval-mae:11.94982
# [500]	train-mae:24.10985	eval-mae:11.90055
# [501]	train-mae:23.96149	eval-mae:11.86137
# [502]	train-mae:23.81673	eval-mae:11.82678
# [503]	train-mae:23.67210	eval-mae:11.79087
# [504]	train-mae:23.53001	eval-mae:11.75612
# [505]	train-mae:23.39191	eval-mae:11.72791
# [506]	train-mae:23.25333	eval-mae:11.68968
# [507]	train-mae:23.11685	eval-mae:11.65348
# [508]	train-mae:22.99157	eval-mae:11.64010
# [509]	train-mae:22.85911	eval-mae:11.60384
# [510]	train-mae:22.72717	eval-mae:11.56806
# [511]	train-mae:22.59782	eval-mae:11.52474
# [512]	train-mae:22.46985	eval-mae:11.49851
# [513]	train-mae:22.34661	eval-mae:11.46821
# [514]	train-mae:22.22162	eval-mae:11.42714
# [515]	train-mae:22.09952	eval-mae:11.38398
# [516]	train-mae:21.98154	eval-mae:11.35685
# [517]	train-mae:21.86195	eval-mae:11.32196
# [518]	train-mae:21.74328	eval-mae:11.29114
# [519]	train-mae:21.62854	eval-mae:11.25558
# [520]	train-mae:21.51533	eval-mae:11.22874
# [521]	train-mae:21.40327	eval-mae:11.19524
# [522]	train-mae:21.29209	eval-mae:11.16865
# [523]	train-mae:21.18154	eval-mae:11.13979
# [524]	train-mae:21.07302	eval-mae:11.10772
# [525]	train-mae:20.96675	eval-mae:11.08027
# [526]	train-mae:20.86339	eval-mae:11.05190
# [527]	train-mae:20.75882	eval-mae:11.02500
# [528]	train-mae:20.65771	eval-mae:10.99783
# [529]	train-mae:20.55782	eval-mae:10.97102
# [530]	train-mae:20.45790	eval-mae:10.94668
# [531]	train-mae:20.35948	eval-mae:10.91386
# [532]	train-mae:20.26287	eval-mae:10.89316
# [533]	train-mae:20.16790	eval-mae:10.86680
# [534]	train-mae:20.07488	eval-mae:10.84460
# [535]	train-mae:19.98201	eval-mae:10.82284
# [536]	train-mae:19.88913	eval-mae:10.79439
# [537]	train-mae:19.80043	eval-mae:10.76589
# [538]	train-mae:19.71321	eval-mae:10.75166
# [539]	train-mae:19.62567	eval-mae:10.72786
# [540]	train-mae:19.54184	eval-mae:10.71419
# [541]	train-mae:19.45744	eval-mae:10.69170
# [542]	train-mae:19.37450	eval-mae:10.66909
# [543]	train-mae:19.29460	eval-mae:10.65454
# [544]	train-mae:19.21613	eval-mae:10.63697
# [545]	train-mae:19.13682	eval-mae:10.61503
# [546]	train-mae:19.05999	eval-mae:10.59757
# [547]	train-mae:18.98245	eval-mae:10.57366
# [548]	train-mae:18.90736	eval-mae:10.55355
# [549]	train-mae:18.83226	eval-mae:10.53299
# [550]	train-mae:18.75895	eval-mae:10.51363
# [551]	train-mae:18.68642	eval-mae:10.49130
# [552]	train-mae:18.61374	eval-mae:10.46162
# [553]	train-mae:18.54039	eval-mae:10.43603
# [554]	train-mae:18.46931	eval-mae:10.41386
# [555]	train-mae:18.40097	eval-mae:10.39650
# [556]	train-mae:18.33370	eval-mae:10.37873
# [557]	train-mae:18.26753	eval-mae:10.36370
# [558]	train-mae:18.20107	eval-mae:10.34353
# [559]	train-mae:18.13493	eval-mae:10.32544
# [560]	train-mae:18.07105	eval-mae:10.31038
# [561]	train-mae:18.00878	eval-mae:10.29452
# [562]	train-mae:17.94588	eval-mae:10.27310
# [563]	train-mae:17.88380	eval-mae:10.25838
# [564]	train-mae:17.82482	eval-mae:10.24766
# [565]	train-mae:17.76435	eval-mae:10.22694
# [566]	train-mae:17.70626	eval-mae:10.20472
# [567]	train-mae:17.64787	eval-mae:10.18423
# [568]	train-mae:17.58976	eval-mae:10.16053
# [569]	train-mae:17.53194	eval-mae:10.13791
# [570]	train-mae:17.47810	eval-mae:10.12311
# [571]	train-mae:17.42342	eval-mae:10.10561
# [572]	train-mae:17.36923	eval-mae:10.09032
# [573]	train-mae:17.31632	eval-mae:10.07513
# [574]	train-mae:17.26441	eval-mae:10.06044
# [575]	train-mae:17.21258	eval-mae:10.04259
# [576]	train-mae:17.16193	eval-mae:10.03379
# [577]	train-mae:17.11182	eval-mae:10.01725
# [578]	train-mae:17.06407	eval-mae:10.00223
# [579]	train-mae:17.01533	eval-mae:9.98610
# [580]	train-mae:16.96995	eval-mae:9.98071
# [581]	train-mae:16.92214	eval-mae:9.96096
# [582]	train-mae:16.87582	eval-mae:9.94785
# [583]	train-mae:16.82974	eval-mae:9.93654
# [584]	train-mae:16.78390	eval-mae:9.91968
# [585]	train-mae:16.73920	eval-mae:9.90215
# [586]	train-mae:16.69535	eval-mae:9.89011
# [587]	train-mae:16.65222	eval-mae:9.87285
# [588]	train-mae:16.60876	eval-mae:9.85633
# [589]	train-mae:16.56761	eval-mae:9.84562
# [590]	train-mae:16.52715	eval-mae:9.82918
# [591]	train-mae:16.48788	eval-mae:9.81733
# [592]	train-mae:16.44898	eval-mae:9.81040
# [593]	train-mae:16.40912	eval-mae:9.79740
# [594]	train-mae:16.36964	eval-mae:9.78269
# [595]	train-mae:16.33286	eval-mae:9.77565
# [596]	train-mae:16.29619	eval-mae:9.75905
# [597]	train-mae:16.25977	eval-mae:9.74875
# [598]	train-mae:16.22304	eval-mae:9.73321
# [599]	train-mae:16.18699	eval-mae:9.71827
# [600]	train-mae:16.15331	eval-mae:9.71284
# [601]	train-mae:16.11808	eval-mae:9.69948
# [602]	train-mae:16.08362	eval-mae:9.68404
# [603]	train-mae:16.04962	eval-mae:9.67146
# [604]	train-mae:16.01581	eval-mae:9.66063
# [605]	train-mae:15.98281	eval-mae:9.65082
# [606]	train-mae:15.95062	eval-mae:9.64100
# [607]	train-mae:15.91857	eval-mae:9.62636
# [608]	train-mae:15.88782	eval-mae:9.61738
# [609]	train-mae:15.85697	eval-mae:9.61080
# [610]	train-mae:15.82673	eval-mae:9.60091
# [611]	train-mae:15.79746	eval-mae:9.59114
# [612]	train-mae:15.76754	eval-mae:9.57853
# [613]	train-mae:15.73886	eval-mae:9.56711
# [614]	train-mae:15.71144	eval-mae:9.56005
# [615]	train-mae:15.68265	eval-mae:9.54938
# [616]	train-mae:15.65524	eval-mae:9.53765
# [617]	train-mae:15.62696	eval-mae:9.52782
# [618]	train-mae:15.59988	eval-mae:9.51885
# [619]	train-mae:15.57396	eval-mae:9.51274
# [620]	train-mae:15.54670	eval-mae:9.50236
# [621]	train-mae:15.52216	eval-mae:9.49178
# [622]	train-mae:15.49622	eval-mae:9.48109
# [623]	train-mae:15.47148	eval-mae:9.47234
# [624]	train-mae:15.44641	eval-mae:9.46111
# [625]	train-mae:15.42227	eval-mae:9.45043
# [626]	train-mae:15.39811	eval-mae:9.43961
# [627]	train-mae:15.37359	eval-mae:9.43095
# [628]	train-mae:15.34986	eval-mae:9.42355
# [629]	train-mae:15.32543	eval-mae:9.41484
# [630]	train-mae:15.30287	eval-mae:9.40745
# [631]	train-mae:15.28002	eval-mae:9.40027
# [632]	train-mae:15.25781	eval-mae:9.39443
# [633]	train-mae:15.23555	eval-mae:9.38468
# [634]	train-mae:15.21325	eval-mae:9.37373
# [635]	train-mae:15.19245	eval-mae:9.36695
# [636]	train-mae:15.17166	eval-mae:9.36143
# [637]	train-mae:15.15231	eval-mae:9.35914
# [638]	train-mae:15.13239	eval-mae:9.35028
# [639]	train-mae:15.11171	eval-mae:9.34566
# [640]	train-mae:15.09148	eval-mae:9.33630
# [641]	train-mae:15.07208	eval-mae:9.32699
# [642]	train-mae:15.05220	eval-mae:9.31969
# [643]	train-mae:15.03523	eval-mae:9.31778
# [644]	train-mae:15.01688	eval-mae:9.31271
# [645]	train-mae:14.99835	eval-mae:9.30516
# [646]	train-mae:14.97930	eval-mae:9.29586
# [647]	train-mae:14.96156	eval-mae:9.28941
# [648]	train-mae:14.94426	eval-mae:9.28373
# [649]	train-mae:14.92755	eval-mae:9.28240
# [650]	train-mae:14.90867	eval-mae:9.27152
# [651]	train-mae:14.89272	eval-mae:9.26573
# [652]	train-mae:14.87537	eval-mae:9.26063
# [653]	train-mae:14.85898	eval-mae:9.25503
# [654]	train-mae:14.84220	eval-mae:9.25093
# [655]	train-mae:14.82573	eval-mae:9.24149
# [656]	train-mae:14.80941	eval-mae:9.23510
# [657]	train-mae:14.79398	eval-mae:9.23116
# [658]	train-mae:14.77853	eval-mae:9.22608
# [659]	train-mae:14.76245	eval-mae:9.21962
# [660]	train-mae:14.74729	eval-mae:9.21374
# [661]	train-mae:14.73192	eval-mae:9.20262
# [662]	train-mae:14.71642	eval-mae:9.19115
# [663]	train-mae:14.70156	eval-mae:9.18701
# [664]	train-mae:14.68790	eval-mae:9.18443
# [665]	train-mae:14.67359	eval-mae:9.17813
# [666]	train-mae:14.65955	eval-mae:9.17136
# [667]	train-mae:14.64650	eval-mae:9.16566
# [668]	train-mae:14.63286	eval-mae:9.15852
# [669]	train-mae:14.62026	eval-mae:9.15552
# [670]	train-mae:14.60671	eval-mae:9.15008
# [671]	train-mae:14.59401	eval-mae:9.14338
# [672]	train-mae:14.58137	eval-mae:9.13889
# [673]	train-mae:14.56836	eval-mae:9.12904
# [674]	train-mae:14.55598	eval-mae:9.12156
# [675]	train-mae:14.54384	eval-mae:9.11501
# [676]	train-mae:14.53174	eval-mae:9.11186
# [677]	train-mae:14.51949	eval-mae:9.10435
# [678]	train-mae:14.50819	eval-mae:9.09954
# [679]	train-mae:14.49682	eval-mae:9.09349
# [680]	train-mae:14.48518	eval-mae:9.08960
# [681]	train-mae:14.47324	eval-mae:9.08340
# [682]	train-mae:14.46198	eval-mae:9.07876
# [683]	train-mae:14.45099	eval-mae:9.07389
# [684]	train-mae:14.44002	eval-mae:9.06752
# [685]	train-mae:14.42938	eval-mae:9.06306
# [686]	train-mae:14.41717	eval-mae:9.05726
# [687]	train-mae:14.40698	eval-mae:9.05363
# [688]	train-mae:14.39533	eval-mae:9.04729
# [689]	train-mae:14.38493	eval-mae:9.04097
# [690]	train-mae:14.37381	eval-mae:9.03541
# [691]	train-mae:14.36338	eval-mae:9.03205
# [692]	train-mae:14.35226	eval-mae:9.02616
# [693]	train-mae:14.34260	eval-mae:9.02011
# [694]	train-mae:14.33211	eval-mae:9.01719
# [695]	train-mae:14.32107	eval-mae:9.01163
# [696]	train-mae:14.31144	eval-mae:9.00483
# [697]	train-mae:14.30167	eval-mae:9.00052
# [698]	train-mae:14.29228	eval-mae:8.99587
# [699]	train-mae:14.28236	eval-mae:8.99217
# [700]	train-mae:14.27278	eval-mae:8.98815
# [701]	train-mae:14.26328	eval-mae:8.98435
# [702]	train-mae:14.25478	eval-mae:8.98362
# [703]	train-mae:14.24594	eval-mae:8.98004
# [704]	train-mae:14.23781	eval-mae:8.97580
# [705]	train-mae:14.22899	eval-mae:8.97132
# [706]	train-mae:14.22047	eval-mae:8.96718
# [707]	train-mae:14.21184	eval-mae:8.96362
# [708]	train-mae:14.20381	eval-mae:8.95854
# [709]	train-mae:14.19560	eval-mae:8.95647
# [710]	train-mae:14.18735	eval-mae:8.95430
# [711]	train-mae:14.17884	eval-mae:8.94963
# [712]	train-mae:14.17092	eval-mae:8.94588
# [713]	train-mae:14.16255	eval-mae:8.94153
# [714]	train-mae:14.15451	eval-mae:8.93745
# [715]	train-mae:14.14609	eval-mae:8.93467
# [716]	train-mae:14.13847	eval-mae:8.93115
# [717]	train-mae:14.13185	eval-mae:8.92858
# [718]	train-mae:14.12485	eval-mae:8.92364
# [719]	train-mae:14.11786	eval-mae:8.91948
# [720]	train-mae:14.11031	eval-mae:8.91447
# [721]	train-mae:14.10278	eval-mae:8.91067
# [722]	train-mae:14.09445	eval-mae:8.90679
# [723]	train-mae:14.08679	eval-mae:8.90392
# [724]	train-mae:14.07966	eval-mae:8.90022
# [725]	train-mae:14.07186	eval-mae:8.89656
# [726]	train-mae:14.06466	eval-mae:8.89244
# [727]	train-mae:14.05726	eval-mae:8.88787
# [728]	train-mae:14.05043	eval-mae:8.88390
# [729]	train-mae:14.04332	eval-mae:8.88047
# [730]	train-mae:14.03628	eval-mae:8.87686
# [731]	train-mae:14.02990	eval-mae:8.87420
# [732]	train-mae:14.02368	eval-mae:8.87336
# [733]	train-mae:14.01655	eval-mae:8.87153
# [734]	train-mae:14.01038	eval-mae:8.86753
# [735]	train-mae:14.00484	eval-mae:8.86581
# [736]	train-mae:13.99905	eval-mae:8.86423
# [737]	train-mae:13.99271	eval-mae:8.86169
# [738]	train-mae:13.98692	eval-mae:8.85999
# [739]	train-mae:13.98059	eval-mae:8.85741
# [740]	train-mae:13.97465	eval-mae:8.85493
# [741]	train-mae:13.96783	eval-mae:8.85125
# [742]	train-mae:13.96182	eval-mae:8.84900
# [743]	train-mae:13.95620	eval-mae:8.84703
# [744]	train-mae:13.95085	eval-mae:8.84608
# [745]	train-mae:13.94449	eval-mae:8.84110
# [746]	train-mae:13.93752	eval-mae:8.84049
# [747]	train-mae:13.93231	eval-mae:8.83844
# [748]	train-mae:13.92594	eval-mae:8.83419
# [749]	train-mae:13.92044	eval-mae:8.82875
# [750]	train-mae:13.91496	eval-mae:8.82488
# [751]	train-mae:13.90881	eval-mae:8.82350
# [752]	train-mae:13.90357	eval-mae:8.82164
# [753]	train-mae:13.89799	eval-mae:8.81990
# [754]	train-mae:13.89170	eval-mae:8.81658
# [755]	train-mae:13.88632	eval-mae:8.81534
# [756]	train-mae:13.88117	eval-mae:8.81468
# [757]	train-mae:13.87521	eval-mae:8.81153
# [758]	train-mae:13.86987	eval-mae:8.80960
# [759]	train-mae:13.86453	eval-mae:8.80704
# [760]	train-mae:13.85858	eval-mae:8.80463
# [761]	train-mae:13.85257	eval-mae:8.80101
# [762]	train-mae:13.84717	eval-mae:8.79612
# [763]	train-mae:13.84126	eval-mae:8.79267
# [764]	train-mae:13.83569	eval-mae:8.78822
# [765]	train-mae:13.82933	eval-mae:8.78435
# [766]	train-mae:13.82373	eval-mae:8.78294
# [767]	train-mae:13.81913	eval-mae:8.77968
# [768]	train-mae:13.81351	eval-mae:8.77644
# [769]	train-mae:13.80739	eval-mae:8.77359
# [770]	train-mae:13.80161	eval-mae:8.77041
# [771]	train-mae:13.79651	eval-mae:8.76706
# [772]	train-mae:13.79206	eval-mae:8.76492
# [773]	train-mae:13.78615	eval-mae:8.76206
# [774]	train-mae:13.77994	eval-mae:8.75969
# [775]	train-mae:13.77530	eval-mae:8.75908
# [776]	train-mae:13.77043	eval-mae:8.75676
# [777]	train-mae:13.76490	eval-mae:8.75385
# [778]	train-mae:13.76067	eval-mae:8.75205
# [779]	train-mae:13.75664	eval-mae:8.74940
# [780]	train-mae:13.75170	eval-mae:8.74777
# [781]	train-mae:13.74639	eval-mae:8.74580
# [782]	train-mae:13.74139	eval-mae:8.74448
# [783]	train-mae:13.73640	eval-mae:8.74248
# [784]	train-mae:13.73234	eval-mae:8.74009
# [785]	train-mae:13.72726	eval-mae:8.73645
# [786]	train-mae:13.72244	eval-mae:8.73349
# [787]	train-mae:13.71741	eval-mae:8.72981
# [788]	train-mae:13.71375	eval-mae:8.72814
# [789]	train-mae:13.70894	eval-mae:8.72730
# [790]	train-mae:13.70487	eval-mae:8.72668
# [791]	train-mae:13.70044	eval-mae:8.72395
# [792]	train-mae:13.69588	eval-mae:8.72120
# [793]	train-mae:13.69163	eval-mae:8.72034
# [794]	train-mae:13.68613	eval-mae:8.71854
# [795]	train-mae:13.68214	eval-mae:8.71797
# [796]	train-mae:13.67794	eval-mae:8.71688
# [797]	train-mae:13.67376	eval-mae:8.71417
# [798]	train-mae:13.66785	eval-mae:8.70963
# [799]	train-mae:13.66242	eval-mae:8.70818
# [800]	train-mae:13.65749	eval-mae:8.70572
# [801]	train-mae:13.65277	eval-mae:8.70265
# [802]	train-mae:13.64840	eval-mae:8.70085
# [803]	train-mae:13.64421	eval-mae:8.69919
# [804]	train-mae:13.63910	eval-mae:8.69695
# [805]	train-mae:13.63465	eval-mae:8.69514
# [806]	train-mae:13.63065	eval-mae:8.69351
# [807]	train-mae:13.62628	eval-mae:8.69237
# [808]	train-mae:13.62282	eval-mae:8.69064
# [809]	train-mae:13.61856	eval-mae:8.69005
# [810]	train-mae:13.61439	eval-mae:8.68840
# [811]	train-mae:13.60995	eval-mae:8.68624
# [812]	train-mae:13.60571	eval-mae:8.68462
# [813]	train-mae:13.60115	eval-mae:8.68234
# [814]	train-mae:13.59704	eval-mae:8.68096
# [815]	train-mae:13.59321	eval-mae:8.67881
# [816]	train-mae:13.58907	eval-mae:8.67760
# [817]	train-mae:13.58455	eval-mae:8.67474
# [818]	train-mae:13.58062	eval-mae:8.67301
# [819]	train-mae:13.57611	eval-mae:8.67211
# [820]	train-mae:13.57304	eval-mae:8.66811
# [821]	train-mae:13.56896	eval-mae:8.66786
# [822]	train-mae:13.56562	eval-mae:8.66681
# [823]	train-mae:13.56235	eval-mae:8.66571
# [824]	train-mae:13.55854	eval-mae:8.66342
# [825]	train-mae:13.55571	eval-mae:8.66286
# [826]	train-mae:13.55210	eval-mae:8.66124
# [827]	train-mae:13.54821	eval-mae:8.65999
# [828]	train-mae:13.54452	eval-mae:8.65886
# [829]	train-mae:13.54028	eval-mae:8.65706
# [830]	train-mae:13.53671	eval-mae:8.65208
# [831]	train-mae:13.53346	eval-mae:8.65119
# [832]	train-mae:13.53017	eval-mae:8.64881
# [833]	train-mae:13.52777	eval-mae:8.64784
# [834]	train-mae:13.52302	eval-mae:8.64487
# [835]	train-mae:13.51976	eval-mae:8.64386
# [836]	train-mae:13.51496	eval-mae:8.64162
# [837]	train-mae:13.51180	eval-mae:8.64064
# [838]	train-mae:13.50785	eval-mae:8.63957
# [839]	train-mae:13.50469	eval-mae:8.63759
# [840]	train-mae:13.49989	eval-mae:8.63552
# [841]	train-mae:13.49701	eval-mae:8.63520
# [842]	train-mae:13.49321	eval-mae:8.63270
# [843]	train-mae:13.48983	eval-mae:8.63116
# [844]	train-mae:13.48581	eval-mae:8.62958
# [845]	train-mae:13.48221	eval-mae:8.62818
# [846]	train-mae:13.47803	eval-mae:8.62623
# [847]	train-mae:13.47337	eval-mae:8.62440
# [848]	train-mae:13.47032	eval-mae:8.62321
# [849]	train-mae:13.46629	eval-mae:8.62158
# [850]	train-mae:13.46356	eval-mae:8.61806
# [851]	train-mae:13.46046	eval-mae:8.61678
# [852]	train-mae:13.45743	eval-mae:8.61630
# [853]	train-mae:13.45332	eval-mae:8.61496
# [854]	train-mae:13.45061	eval-mae:8.61361
# [855]	train-mae:13.44847	eval-mae:8.61400
# [856]	train-mae:13.44537	eval-mae:8.61293
# [857]	train-mae:13.44200	eval-mae:8.61130
# [858]	train-mae:13.43839	eval-mae:8.61017
# [859]	train-mae:13.43411	eval-mae:8.60866
# [860]	train-mae:13.43062	eval-mae:8.60648
# [861]	train-mae:13.42774	eval-mae:8.60562
# [862]	train-mae:13.42474	eval-mae:8.60545
# [863]	train-mae:13.42173	eval-mae:8.60504
# [864]	train-mae:13.41813	eval-mae:8.60274
# [865]	train-mae:13.41517	eval-mae:8.60175
# [866]	train-mae:13.41190	eval-mae:8.60147
# [867]	train-mae:13.40850	eval-mae:8.60055
# [868]	train-mae:13.40527	eval-mae:8.59963
# [869]	train-mae:13.40248	eval-mae:8.59812
# [870]	train-mae:13.39885	eval-mae:8.59702
# [871]	train-mae:13.39524	eval-mae:8.59538
# [872]	train-mae:13.39233	eval-mae:8.59415
# [873]	train-mae:13.38893	eval-mae:8.59296
# [874]	train-mae:13.38599	eval-mae:8.59113
# [875]	train-mae:13.38281	eval-mae:8.58991
# [876]	train-mae:13.38027	eval-mae:8.58911
# [877]	train-mae:13.37810	eval-mae:8.58869
# [878]	train-mae:13.37537	eval-mae:8.58829
# [879]	train-mae:13.37278	eval-mae:8.58800
# [880]	train-mae:13.37034	eval-mae:8.58654
# [881]	train-mae:13.36727	eval-mae:8.58267
# [882]	train-mae:13.36471	eval-mae:8.58201
# [883]	train-mae:13.36151	eval-mae:8.58027
# [884]	train-mae:13.35855	eval-mae:8.57902
# [885]	train-mae:13.35537	eval-mae:8.57900
# [886]	train-mae:13.35298	eval-mae:8.57893
# [887]	train-mae:13.34977	eval-mae:8.57814
# [888]	train-mae:13.34687	eval-mae:8.57791
# [889]	train-mae:13.34376	eval-mae:8.57767
# [890]	train-mae:13.34043	eval-mae:8.57660
# [891]	train-mae:13.33848	eval-mae:8.57623
# [892]	train-mae:13.33603	eval-mae:8.57505
# [893]	train-mae:13.33303	eval-mae:8.57435
# [894]	train-mae:13.33053	eval-mae:8.57409
# [895]	train-mae:13.32804	eval-mae:8.57315
# [896]	train-mae:13.32458	eval-mae:8.57245
# [897]	train-mae:13.32129	eval-mae:8.57129
# [898]	train-mae:13.31890	eval-mae:8.57072
# [899]	train-mae:13.31559	eval-mae:8.57028
# [900]	train-mae:13.31255	eval-mae:8.56978
# [901]	train-mae:13.31016	eval-mae:8.56974
# [902]	train-mae:13.30726	eval-mae:8.56923
# [903]	train-mae:13.30416	eval-mae:8.56854
# [904]	train-mae:13.30097	eval-mae:8.56772
# [905]	train-mae:13.29820	eval-mae:8.56643
# [906]	train-mae:13.29570	eval-mae:8.56594
# [907]	train-mae:13.29301	eval-mae:8.56417
# [908]	train-mae:13.28960	eval-mae:8.56260
# [909]	train-mae:13.28629	eval-mae:8.56178
# [910]	train-mae:13.28353	eval-mae:8.56071
# [911]	train-mae:13.28096	eval-mae:8.56000
# [912]	train-mae:13.27806	eval-mae:8.55888
# [913]	train-mae:13.27587	eval-mae:8.55660
# [914]	train-mae:13.27265	eval-mae:8.55613
# [915]	train-mae:13.27018	eval-mae:8.55575
# [916]	train-mae:13.26761	eval-mae:8.55520
# [917]	train-mae:13.26532	eval-mae:8.55486
# [918]	train-mae:13.26245	eval-mae:8.55494
# [919]	train-mae:13.25995	eval-mae:8.55370
# [920]	train-mae:13.25691	eval-mae:8.55290
# [921]	train-mae:13.25431	eval-mae:8.55236
# [922]	train-mae:13.25247	eval-mae:8.55142
# [923]	train-mae:13.25036	eval-mae:8.55084
# [924]	train-mae:13.24722	eval-mae:8.54762
# [925]	train-mae:13.24433	eval-mae:8.54669
# [926]	train-mae:13.24106	eval-mae:8.54637
# [927]	train-mae:13.23840	eval-mae:8.54599
# [928]	train-mae:13.23621	eval-mae:8.54592
# [929]	train-mae:13.23273	eval-mae:8.54401
# [930]	train-mae:13.23049	eval-mae:8.54329
# [931]	train-mae:13.22820	eval-mae:8.54326
# [932]	train-mae:13.22624	eval-mae:8.54324
# [933]	train-mae:13.22340	eval-mae:8.54260
# [934]	train-mae:13.22076	eval-mae:8.54192
# [935]	train-mae:13.21844	eval-mae:8.54134
# [936]	train-mae:13.21552	eval-mae:8.53979
# [937]	train-mae:13.21263	eval-mae:8.53963
# [938]	train-mae:13.21055	eval-mae:8.53986
# [939]	train-mae:13.20824	eval-mae:8.53822
# [940]	train-mae:13.20614	eval-mae:8.53744
# [941]	train-mae:13.20381	eval-mae:8.53517
# [942]	train-mae:13.20103	eval-mae:8.53476
# [943]	train-mae:13.19859	eval-mae:8.53454
# [944]	train-mae:13.19619	eval-mae:8.53436
# [945]	train-mae:13.19340	eval-mae:8.53419
# [946]	train-mae:13.19189	eval-mae:8.53385
# [947]	train-mae:13.18949	eval-mae:8.53328
# [948]	train-mae:13.18652	eval-mae:8.53205
# [949]	train-mae:13.18371	eval-mae:8.53054
# [950]	train-mae:13.18123	eval-mae:8.53007
# [951]	train-mae:13.17923	eval-mae:8.52935
# [952]	train-mae:13.17641	eval-mae:8.52869
# [953]	train-mae:13.17416	eval-mae:8.52843
# [954]	train-mae:13.17194	eval-mae:8.52817
# [955]	train-mae:13.16927	eval-mae:8.52780
# [956]	train-mae:13.16621	eval-mae:8.52794
# [957]	train-mae:13.16379	eval-mae:8.52731
# [958]	train-mae:13.16154	eval-mae:8.52662
# [959]	train-mae:13.15981	eval-mae:8.52639
# [960]	train-mae:13.15787	eval-mae:8.52503
# [961]	train-mae:13.15571	eval-mae:8.52434
# [962]	train-mae:13.15306	eval-mae:8.52404
# [963]	train-mae:13.15068	eval-mae:8.52373
# [964]	train-mae:13.14795	eval-mae:8.52272
# [965]	train-mae:13.14508	eval-mae:8.52222
# [966]	train-mae:13.14266	eval-mae:8.52179
# [967]	train-mae:13.14058	eval-mae:8.52141
# [968]	train-mae:13.13744	eval-mae:8.52115
# [969]	train-mae:13.13502	eval-mae:8.52074
# [970]	train-mae:13.13265	eval-mae:8.52042
# [971]	train-mae:13.13013	eval-mae:8.51951
# [972]	train-mae:13.12836	eval-mae:8.51870
# [973]	train-mae:13.12642	eval-mae:8.51855
# [974]	train-mae:13.12408	eval-mae:8.51771
# [975]	train-mae:13.12140	eval-mae:8.51709
# [976]	train-mae:13.11932	eval-mae:8.51672
# [977]	train-mae:13.11728	eval-mae:8.51660
# [978]	train-mae:13.11529	eval-mae:8.51382
# [979]	train-mae:13.11378	eval-mae:8.51378
# [980]	train-mae:13.11069	eval-mae:8.51211
# [981]	train-mae:13.10904	eval-mae:8.51058
# [982]	train-mae:13.10757	eval-mae:8.51048
# [983]	train-mae:13.10568	eval-mae:8.50981
# [984]	train-mae:13.10298	eval-mae:8.50957
# [985]	train-mae:13.10069	eval-mae:8.50928
# [986]	train-mae:13.09891	eval-mae:8.50865
# [987]	train-mae:13.09701	eval-mae:8.50789
# [988]	train-mae:13.09528	eval-mae:8.50782
# [989]	train-mae:13.09377	eval-mae:8.50703
# [990]	train-mae:13.09140	eval-mae:8.50688
# [991]	train-mae:13.08975	eval-mae:8.50671
# [992]	train-mae:13.08766	eval-mae:8.50652
# [993]	train-mae:13.08517	eval-mae:8.50404
# [994]	train-mae:13.08311	eval-mae:8.50363
# [995]	train-mae:13.08134	eval-mae:8.50347
# [996]	train-mae:13.07965	eval-mae:8.50298
# [997]	train-mae:13.07711	eval-mae:8.50241
# [998]	train-mae:13.07435	eval-mae:8.50184
# [999]	train-mae:13.07202	eval-mae:8.50121
# [1000]	train-mae:13.06984	eval-mae:8.50077
# [1001]	train-mae:13.06789	eval-mae:8.49914
# [1002]	train-mae:13.06579	eval-mae:8.49828
# [1003]	train-mae:13.06402	eval-mae:8.49830
# [1004]	train-mae:13.06204	eval-mae:8.49842
# [1005]	train-mae:13.05981	eval-mae:8.49853
# [1006]	train-mae:13.05782	eval-mae:8.49838
# [1007]	train-mae:13.05620	eval-mae:8.49703
# [1008]	train-mae:13.05419	eval-mae:8.49615
# [1009]	train-mae:13.05202	eval-mae:8.49627
# [1010]	train-mae:13.04977	eval-mae:8.49614
# [1011]	train-mae:13.04821	eval-mae:8.49616
# [1012]	train-mae:13.04619	eval-mae:8.49605
# [1013]	train-mae:13.04411	eval-mae:8.49626
# [1014]	train-mae:13.04179	eval-mae:8.49517
# [1015]	train-mae:13.03989	eval-mae:8.49427
# [1016]	train-mae:13.03748	eval-mae:8.49363
# [1017]	train-mae:13.03549	eval-mae:8.49353
# [1018]	train-mae:13.03353	eval-mae:8.49233
# [1019]	train-mae:13.03150	eval-mae:8.49206
# [1020]	train-mae:13.03001	eval-mae:8.49168
# [1021]	train-mae:13.02823	eval-mae:8.49166
# [1022]	train-mae:13.02635	eval-mae:8.49118
# [1023]	train-mae:13.02444	eval-mae:8.49093
# [1024]	train-mae:13.02243	eval-mae:8.49055
# [1025]	train-mae:13.02045	eval-mae:8.48991
# [1026]	train-mae:13.01854	eval-mae:8.48978
# [1027]	train-mae:13.01648	eval-mae:8.48900
# [1028]	train-mae:13.01422	eval-mae:8.48931
# [1029]	train-mae:13.01205	eval-mae:8.48927
# [1030]	train-mae:13.00999	eval-mae:8.48843
# [1031]	train-mae:13.00815	eval-mae:8.48788
# [1032]	train-mae:13.00622	eval-mae:8.48733
# [1033]	train-mae:13.00380	eval-mae:8.48681
# [1034]	train-mae:13.00140	eval-mae:8.48535
# [1035]	train-mae:12.99924	eval-mae:8.48533
# [1036]	train-mae:12.99681	eval-mae:8.48475
# [1037]	train-mae:12.99429	eval-mae:8.48375
# [1038]	train-mae:12.99206	eval-mae:8.48281
# [1039]	train-mae:12.98981	eval-mae:8.48249
# [1040]	train-mae:12.98775	eval-mae:8.48215
# [1041]	train-mae:12.98591	eval-mae:8.48165
# [1042]	train-mae:12.98392	eval-mae:8.48150
# [1043]	train-mae:12.98207	eval-mae:8.48078
# [1044]	train-mae:12.97946	eval-mae:8.48049
# [1045]	train-mae:12.97735	eval-mae:8.47952
# [1046]	train-mae:12.97516	eval-mae:8.47864
# [1047]	train-mae:12.97340	eval-mae:8.47846
# [1048]	train-mae:12.97166	eval-mae:8.47817
# [1049]	train-mae:12.97020	eval-mae:8.47741
# [1050]	train-mae:12.96828	eval-mae:8.47652
# [1051]	train-mae:12.96668	eval-mae:8.47652
# [1052]	train-mae:12.96508	eval-mae:8.47628
# [1053]	train-mae:12.96301	eval-mae:8.47241
# [1054]	train-mae:12.96107	eval-mae:8.47160
# [1055]	train-mae:12.95919	eval-mae:8.47123
# [1056]	train-mae:12.95727	eval-mae:8.47093
# [1057]	train-mae:12.95528	eval-mae:8.46983
# [1058]	train-mae:12.95320	eval-mae:8.46922
# [1059]	train-mae:12.95088	eval-mae:8.46975
# [1060]	train-mae:12.94873	eval-mae:8.46961
# [1061]	train-mae:12.94670	eval-mae:8.46921
# [1062]	train-mae:12.94482	eval-mae:8.46932
# [1063]	train-mae:12.94329	eval-mae:8.46932
# [1064]	train-mae:12.94196	eval-mae:8.46860
# [1065]	train-mae:12.94019	eval-mae:8.46824
# [1066]	train-mae:12.93851	eval-mae:8.46814
# [1067]	train-mae:12.93677	eval-mae:8.46779
# [1068]	train-mae:12.93523	eval-mae:8.46779
# [1069]	train-mae:12.93341	eval-mae:8.46702
# [1070]	train-mae:12.93165	eval-mae:8.46698
# [1071]	train-mae:12.92944	eval-mae:8.46682
# [1072]	train-mae:12.92820	eval-mae:8.46640
# [1073]	train-mae:12.92611	eval-mae:8.46466
# [1074]	train-mae:12.92454	eval-mae:8.46427
# [1075]	train-mae:12.92222	eval-mae:8.46342
# [1076]	train-mae:12.92010	eval-mae:8.46185
# [1077]	train-mae:12.91862	eval-mae:8.46136
# [1078]	train-mae:12.91653	eval-mae:8.46099
# [1079]	train-mae:12.91449	eval-mae:8.46042
# [1080]	train-mae:12.91238	eval-mae:8.46016
# [1081]	train-mae:12.91122	eval-mae:8.45996
# [1082]	train-mae:12.90925	eval-mae:8.45947
# [1083]	train-mae:12.90713	eval-mae:8.45943
# [1084]	train-mae:12.90496	eval-mae:8.45936
# [1085]	train-mae:12.90324	eval-mae:8.45895
# [1086]	train-mae:12.90142	eval-mae:8.45832
# [1087]	train-mae:12.89888	eval-mae:8.45826
# [1088]	train-mae:12.89730	eval-mae:8.45818
# [1089]	train-mae:12.89451	eval-mae:8.45697
# [1090]	train-mae:12.89251	eval-mae:8.45562
# [1091]	train-mae:12.89072	eval-mae:8.45500
# [1092]	train-mae:12.88918	eval-mae:8.45450
# [1093]	train-mae:12.88709	eval-mae:8.45353
# [1094]	train-mae:12.88508	eval-mae:8.45352
# [1095]	train-mae:12.88310	eval-mae:8.45313
# [1096]	train-mae:12.88134	eval-mae:8.45272
# [1097]	train-mae:12.87931	eval-mae:8.44929
# [1098]	train-mae:12.87672	eval-mae:8.44843
# [1099]	train-mae:12.87447	eval-mae:8.44893
# [1100]	train-mae:12.87250	eval-mae:8.44843
# [1101]	train-mae:12.87071	eval-mae:8.44840
# [1102]	train-mae:12.86874	eval-mae:8.44792
# [1103]	train-mae:12.86651	eval-mae:8.44754
# [1104]	train-mae:12.86387	eval-mae:8.44696
# [1105]	train-mae:12.86259	eval-mae:8.44619
# [1106]	train-mae:12.86091	eval-mae:8.44587
# [1107]	train-mae:12.85872	eval-mae:8.44569
# [1108]	train-mae:12.85742	eval-mae:8.44541
# [1109]	train-mae:12.85510	eval-mae:8.44397
# ...
# [1628]	train-mae:12.09210	eval-mae:8.21966
# [1629]	train-mae:12.09061	eval-mae:8.21965
# [1630]	train-mae:12.08890	eval-mae:8.21930
# [1631]	train-mae:12.08781	eval-mae:8.21926
# [1632]	train-mae:12.08663	eval-mae:8.21922
# [1633]	train-mae:12.08525	eval-mae:8.21922
# [1634]	train-mae:12.08466	eval-mae:8.21917
# [1635]	train-mae:12.08336	eval-mae:8.21888
# [1636]	train-mae:12.08215	eval-mae:8.21883
# [1637]	train-mae:12.07968	eval-mae:8.21585
# [1638]	train-mae:12.07817	eval-mae:8.21554
# [1639]	train-mae:12.07726	eval-mae:8.21546
# [1640]	train-mae:12.07627	eval-mae:8.21494
# [1641]	train-mae:12.07500	eval-mae:8.21486
# [1642]	train-mae:12.07363	eval-mae:8.21477
# [1643]	train-mae:12.07257	eval-mae:8.21477
# [1644]	train-mae:12.07165	eval-mae:8.21474
# [1645]	train-mae:12.07085	eval-mae:8.21474
# [1646]	train-mae:12.06952	eval-mae:8.21464
# [1647]	train-mae:12.06829	eval-mae:8.21459
# [1648]	train-mae:12.06669	eval-mae:8.21458
# [1649]	train-mae:12.06555	eval-mae:8.21442
# [1650]	train-mae:12.06408	eval-mae:8.21436
# [1651]	train-mae:12.06265	eval-mae:8.21423
# [1652]	train-mae:12.06172	eval-mae:8.21416
# [1653]	train-mae:12.06032	eval-mae:8.21403
# [1654]	train-mae:12.05924	eval-mae:8.21379
# [1655]	train-mae:12.05837	eval-mae:8.21365
# [1656]	train-mae:12.05733	eval-mae:8.21352
# [1657]	train-mae:12.05574	eval-mae:8.21316
# [1658]	train-mae:12.05464	eval-mae:8.21309
# [1659]	train-mae:12.05381	eval-mae:8.21315
# [1660]	train-mae:12.05230	eval-mae:8.21319
# [1661]	train-mae:12.05141	eval-mae:8.21316
# [1662]	train-mae:12.05017	eval-mae:8.21317
# [1663]	train-mae:12.04841	eval-mae:8.21318
# [1664]	train-mae:12.04717	eval-mae:8.21318
# [1665]	train-mae:12.04623	eval-mae:8.21317
# [1666]	train-mae:12.04497	eval-mae:8.21325
# [1667]	train-mae:12.04346	eval-mae:8.21250
# [1668]	train-mae:12.04219	eval-mae:8.21237
# [1669]	train-mae:12.04145	eval-mae:8.21179
# [1670]	train-mae:12.04045	eval-mae:8.21173
# [1671]	train-mae:12.03919	eval-mae:8.21168
# [1672]	train-mae:12.03798	eval-mae:8.21168
# [1673]	train-mae:12.03679	eval-mae:8.21139
# [1674]	train-mae:12.03515	eval-mae:8.21129
# [1675]	train-mae:12.03402	eval-mae:8.21130
# [1676]	train-mae:12.03220	eval-mae:8.21130
# [1677]	train-mae:12.03076	eval-mae:8.21131
# [1678]	train-mae:12.02987	eval-mae:8.21142
# [1679]	train-mae:12.02898	eval-mae:8.21121
# [1680]	train-mae:12.02684	eval-mae:8.20718
# [1681]	train-mae:12.02512	eval-mae:8.20714
# [1682]	train-mae:12.02431	eval-mae:8.20693
# [1683]	train-mae:12.02356	eval-mae:8.20677
# [1684]	train-mae:12.02242	eval-mae:8.20642
# [1685]	train-mae:12.02144	eval-mae:8.20641
# [1686]	train-mae:12.02022	eval-mae:8.20641
# [1687]	train-mae:12.01912	eval-mae:8.20559
# [1688]	train-mae:12.01829	eval-mae:8.20560
# [1689]	train-mae:12.01726	eval-mae:8.20559
# [1690]	train-mae:12.01621	eval-mae:8.20558
# [1691]	train-mae:12.01459	eval-mae:8.20056
# [1692]	train-mae:12.01362	eval-mae:8.20056
# [1693]	train-mae:12.01214	eval-mae:8.20055
# [1694]	train-mae:12.01112	eval-mae:8.20049
# [1695]	train-mae:12.01023	eval-mae:8.20046
# [1696]	train-mae:12.00923	eval-mae:8.20046
# [1697]	train-mae:12.00769	eval-mae:8.20046
# [1698]	train-mae:12.00665	eval-mae:8.20045
# [1699]	train-mae:12.00537	eval-mae:8.20019
# [1700]	train-mae:12.00365	eval-mae:8.20020
# [1701]	train-mae:12.00222	eval-mae:8.19993
# [1702]	train-mae:12.00080	eval-mae:8.19986
# [1703]	train-mae:11.99965	eval-mae:8.19980
# [1704]	train-mae:11.99831	eval-mae:8.19973
# [1705]	train-mae:11.99731	eval-mae:8.19973
# [1706]	train-mae:11.99649	eval-mae:8.19961
# [1707]	train-mae:11.99575	eval-mae:8.19961
# [1708]	train-mae:11.99477	eval-mae:8.19961
# [1709]	train-mae:11.99390	eval-mae:8.19911
# [1710]	train-mae:11.99298	eval-mae:8.19866
# [1711]	train-mae:11.99190	eval-mae:8.19864
# [1712]	train-mae:11.99055	eval-mae:8.19865
# [1713]	train-mae:11.98968	eval-mae:8.19864
# [1714]	train-mae:11.98811	eval-mae:8.19818
# [1715]	train-mae:11.98647	eval-mae:8.19728
# [1716]	train-mae:11.98562	eval-mae:8.19728
# [1717]	train-mae:11.98458	eval-mae:8.19731
# [1718]	train-mae:11.98343	eval-mae:8.19728
# [1719]	train-mae:11.98245	eval-mae:8.19724
# [1720]	train-mae:11.98122	eval-mae:8.19722
# [1721]	train-mae:11.97993	eval-mae:8.19599
# [1722]	train-mae:11.97838	eval-mae:8.19484
# [1723]	train-mae:11.97648	eval-mae:8.18975
# [1724]	train-mae:11.97534	eval-mae:8.18985
# [1725]	train-mae:11.97437	eval-mae:8.18965
# [1726]	train-mae:11.97273	eval-mae:8.18955
# [1727]	train-mae:11.97192	eval-mae:8.18945
# [1728]	train-mae:11.97055	eval-mae:8.18911
# [1729]	train-mae:11.96914	eval-mae:8.18585
# [1730]	train-mae:11.96825	eval-mae:8.18584
# [1731]	train-mae:11.96697	eval-mae:8.18583
# [1732]	train-mae:11.96647	eval-mae:8.18582
# [1733]	train-mae:11.96524	eval-mae:8.18528
# [1734]	train-mae:11.96431	eval-mae:8.18525
# [1735]	train-mae:11.96354	eval-mae:8.18495
# [1736]	train-mae:11.96259	eval-mae:8.18494
# [1737]	train-mae:11.96133	eval-mae:8.18452
# [1738]	train-mae:11.96022	eval-mae:8.18438
# [1739]	train-mae:11.95908	eval-mae:8.18385
# [1740]	train-mae:11.95830	eval-mae:8.18388
# [1741]	train-mae:11.95732	eval-mae:8.18348
# [1742]	train-mae:11.95643	eval-mae:8.18343
# [1743]	train-mae:11.95554	eval-mae:8.18342
# [1744]	train-mae:11.95383	eval-mae:8.18342
# [1745]	train-mae:11.95285	eval-mae:8.18342
# [1746]	train-mae:11.95192	eval-mae:8.18354
# [1747]	train-mae:11.95064	eval-mae:8.18321
# [1748]	train-mae:11.94901	eval-mae:8.18303
# [1749]	train-mae:11.94741	eval-mae:8.18297
# [1750]	train-mae:11.94653	eval-mae:8.18262
# [1751]	train-mae:11.94509	eval-mae:8.18258
# [1752]	train-mae:11.94362	eval-mae:8.18246
# [1753]	train-mae:11.94239	eval-mae:8.18224
# [1754]	train-mae:11.94123	eval-mae:8.18204
# [1755]	train-mae:11.93993	eval-mae:8.18153
# [1756]	train-mae:11.93859	eval-mae:8.18153
# [1757]	train-mae:11.93752	eval-mae:8.18147
# [1758]	train-mae:11.93569	eval-mae:8.17992
# [1759]	train-mae:11.93444	eval-mae:8.17991
# [1760]	train-mae:11.93280	eval-mae:8.17594
# [1761]	train-mae:11.93186	eval-mae:8.17594
# [1762]	train-mae:11.93087	eval-mae:8.17569
# [1763]	train-mae:11.92967	eval-mae:8.17490
# [1764]	train-mae:11.92899	eval-mae:8.17492
# [1765]	train-mae:11.92750	eval-mae:8.17448
# [1766]	train-mae:11.92587	eval-mae:8.17455
# [1767]	train-mae:11.92353	eval-mae:8.17205
# [1768]	train-mae:11.92294	eval-mae:8.17208
# [1769]	train-mae:11.92195	eval-mae:8.17218
# [1770]	train-mae:11.92006	eval-mae:8.16912
# [1771]	train-mae:11.91905	eval-mae:8.16840
# [1772]	train-mae:11.91797	eval-mae:8.16839
# [1773]	train-mae:11.91710	eval-mae:8.16839
# [1774]	train-mae:11.91583	eval-mae:8.16853
# [1775]	train-mae:11.91458	eval-mae:8.16853
# [1776]	train-mae:11.91306	eval-mae:8.16825
# [1777]	train-mae:11.91210	eval-mae:8.16812
# [1778]	train-mae:11.91146	eval-mae:8.16808
# [1779]	train-mae:11.91029	eval-mae:8.16716
# [1780]	train-mae:11.90970	eval-mae:8.16690
# [1781]	train-mae:11.90907	eval-mae:8.16692
# [1782]	train-mae:11.90789	eval-mae:8.16668
# [1783]	train-mae:11.90698	eval-mae:8.16616
# [1784]	train-mae:11.90611	eval-mae:8.16616
# [1785]	train-mae:11.90527	eval-mae:8.16603
# [1786]	train-mae:11.90420	eval-mae:8.16602
# [1787]	train-mae:11.90290	eval-mae:8.16534
# [1788]	train-mae:11.90204	eval-mae:8.16534
# [1789]	train-mae:11.90109	eval-mae:8.16530
# [1790]	train-mae:11.89975	eval-mae:8.16495
# [1791]	train-mae:11.89891	eval-mae:8.16485
# [1792]	train-mae:11.89704	eval-mae:8.16484
# [1793]	train-mae:11.89573	eval-mae:8.16459
# [1794]	train-mae:11.89368	eval-mae:8.16458
# [1795]	train-mae:11.89230	eval-mae:8.16458
# [1796]	train-mae:11.89084	eval-mae:8.16457
# [1797]	train-mae:11.88969	eval-mae:8.16458
# [1798]	train-mae:11.88799	eval-mae:8.16467
# [1799]	train-mae:11.88664	eval-mae:8.16458
# [1800]	train-mae:11.88582	eval-mae:8.16440
# [1801]	train-mae:11.88415	eval-mae:8.16418
# [1802]	train-mae:11.88285	eval-mae:8.16121
# [1803]	train-mae:11.88181	eval-mae:8.16122
# [1804]	train-mae:11.88091	eval-mae:8.16123
# [1805]	train-mae:11.87965	eval-mae:8.16043
# [1806]	train-mae:11.87893	eval-mae:8.16043
# [1807]	train-mae:11.87783	eval-mae:8.15881
# [1808]	train-mae:11.87662	eval-mae:8.15835
# [1809]	train-mae:11.87565	eval-mae:8.15833
# [1810]	train-mae:11.87481	eval-mae:8.15832
# [1811]	train-mae:11.87365	eval-mae:8.15837
# [1812]	train-mae:11.87285	eval-mae:8.15833
# [1813]	train-mae:11.87154	eval-mae:8.15775
# [1814]	train-mae:11.87048	eval-mae:8.15765
# [1815]	train-mae:11.86926	eval-mae:8.15735
# [1816]	train-mae:11.86837	eval-mae:8.15735
# [1817]	train-mae:11.86713	eval-mae:8.15701
# [1818]	train-mae:11.86542	eval-mae:8.15688
# [1819]	train-mae:11.86438	eval-mae:8.15648
# [1820]	train-mae:11.86310	eval-mae:8.15648
# [1821]	train-mae:11.86219	eval-mae:8.15629
# [1822]	train-mae:11.86146	eval-mae:8.15607
# [1823]	train-mae:11.86036	eval-mae:8.15603
# [1824]	train-mae:11.85932	eval-mae:8.15603
# [1825]	train-mae:11.85825	eval-mae:8.15603
# [1826]	train-mae:11.85684	eval-mae:8.15575
# [1827]	train-mae:11.85594	eval-mae:8.15564
# [1828]	train-mae:11.85497	eval-mae:8.15569
# [1829]	train-mae:11.85428	eval-mae:8.15571
# [1830]	train-mae:11.85318	eval-mae:8.15569
# [1831]	train-mae:11.85211	eval-mae:8.15555
# [1832]	train-mae:11.85091	eval-mae:8.15554
# [1833]	train-mae:11.84956	eval-mae:8.15546
# [1834]	train-mae:11.84832	eval-mae:8.15248
# [1835]	train-mae:11.84743	eval-mae:8.15248
# [1836]	train-mae:11.84595	eval-mae:8.15248
# [1837]	train-mae:11.84484	eval-mae:8.15248
# [1838]	train-mae:11.84355	eval-mae:8.15257
# [1839]	train-mae:11.84252	eval-mae:8.15253
# [1840]	train-mae:11.84108	eval-mae:8.15263
# [1841]	train-mae:11.84008	eval-mae:8.15260
# [1842]	train-mae:11.83900	eval-mae:8.15255
# [1843]	train-mae:11.83710	eval-mae:8.14983
# [1844]	train-mae:11.83610	eval-mae:8.14940
# [1845]	train-mae:11.83514	eval-mae:8.14897
# [1846]	train-mae:11.83434	eval-mae:8.14896
# [1847]	train-mae:11.83267	eval-mae:8.14878
# [1848]	train-mae:11.83133	eval-mae:8.14842
# [1849]	train-mae:11.83020	eval-mae:8.14829
# [1850]	train-mae:11.82882	eval-mae:8.14837
# [1851]	train-mae:11.82792	eval-mae:8.14836
# [1852]	train-mae:11.82696	eval-mae:8.14829
# [1853]	train-mae:11.82616	eval-mae:8.14829
# [1854]	train-mae:11.82413	eval-mae:8.14606
# [1855]	train-mae:11.82233	eval-mae:8.14121
# [1856]	train-mae:11.82133	eval-mae:8.14113
# [1857]	train-mae:11.82026	eval-mae:8.14109
# [1858]	train-mae:11.81828	eval-mae:8.13838
# [1859]	train-mae:11.81669	eval-mae:8.13815
# [1860]	train-mae:11.81599	eval-mae:8.13816
# [1861]	train-mae:11.81510	eval-mae:8.13818
# [1862]	train-mae:11.81406	eval-mae:8.13826
# [1863]	train-mae:11.81308	eval-mae:8.13818
# [1864]	train-mae:11.81202	eval-mae:8.13804
# [1865]	train-mae:11.81059	eval-mae:8.13533
# [1866]	train-mae:11.80946	eval-mae:8.13532
# [1867]	train-mae:11.80834	eval-mae:8.13532
# [1868]	train-mae:11.80735	eval-mae:8.13532
# [1869]	train-mae:11.80613	eval-mae:8.13529
# [1870]	train-mae:11.80400	eval-mae:8.13252
# [1871]	train-mae:11.80294	eval-mae:8.13245
# [1872]	train-mae:11.80088	eval-mae:8.12536
# [1873]	train-mae:11.79994	eval-mae:8.12534
# [1874]	train-mae:11.79873	eval-mae:8.12534
# [1875]	train-mae:11.79785	eval-mae:8.12478
# [1876]	train-mae:11.79704	eval-mae:8.12463
# [1877]	train-mae:11.79607	eval-mae:8.12455
# [1878]	train-mae:11.79468	eval-mae:8.12455
# [1879]	train-mae:11.79345	eval-mae:8.12430
# [1880]	train-mae:11.79241	eval-mae:8.12430
# [1881]	train-mae:11.79172	eval-mae:8.12429
# [1882]	train-mae:11.79100	eval-mae:8.12426
# [1883]	train-mae:11.78986	eval-mae:8.12425
# [1884]	train-mae:11.78902	eval-mae:8.12426
# [1885]	train-mae:11.78779	eval-mae:8.12427
# [1886]	train-mae:11.78636	eval-mae:8.12428
# [1887]	train-mae:11.78478	eval-mae:8.12318
# [1888]	train-mae:11.78360	eval-mae:8.12318
# [1889]	train-mae:11.78220	eval-mae:8.12321
# [1890]	train-mae:11.78116	eval-mae:8.12283
# [1891]	train-mae:11.78017	eval-mae:8.12297
# [1892]	train-mae:11.77922	eval-mae:8.12289
# [1893]	train-mae:11.77844	eval-mae:8.12288
# [1894]	train-mae:11.77782	eval-mae:8.12275
# [1895]	train-mae:11.77597	eval-mae:8.11945
# [1896]	train-mae:11.77508	eval-mae:8.11944
# [1897]	train-mae:11.77402	eval-mae:8.11920
# [1898]	train-mae:11.77301	eval-mae:8.11893
# [1899]	train-mae:11.77239	eval-mae:8.11893
# [1900]	train-mae:11.77101	eval-mae:8.11873
# [1901]	train-mae:11.77015	eval-mae:8.11873
# [1902]	train-mae:11.76901	eval-mae:8.11871
# [1903]	train-mae:11.76716	eval-mae:8.11862
# [1904]	train-mae:11.76625	eval-mae:8.11870
# [1905]	train-mae:11.76476	eval-mae:8.11871
# [1906]	train-mae:11.76423	eval-mae:8.11867
# [1907]	train-mae:11.76280	eval-mae:8.11845
# [1908]	train-mae:11.76191	eval-mae:8.11803
# [1909]	train-mae:11.76069	eval-mae:8.11786
# [1910]	train-mae:11.75970	eval-mae:8.11731
# [1911]	train-mae:11.75871	eval-mae:8.11731
# [1912]	train-mae:11.75784	eval-mae:8.11707
# [1913]	train-mae:11.75699	eval-mae:8.11698
# [1914]	train-mae:11.75620	eval-mae:8.11648
# [1915]	train-mae:11.75543	eval-mae:8.11627
# [1916]	train-mae:11.75455	eval-mae:8.11606
# [1917]	train-mae:11.75387	eval-mae:8.11601
# [1918]	train-mae:11.75294	eval-mae:8.11589
# [1919]	train-mae:11.75147	eval-mae:8.11555
# [1920]	train-mae:11.75031	eval-mae:8.11509
# [1921]	train-mae:11.74884	eval-mae:8.11480
# [1922]	train-mae:11.74794	eval-mae:8.11480
# [1923]	train-mae:11.74666	eval-mae:8.11460
# [1924]	train-mae:11.74584	eval-mae:8.11419
# [1925]	train-mae:11.74372	eval-mae:8.11177
# [1926]	train-mae:11.74286	eval-mae:8.11176
# [1927]	train-mae:11.74200	eval-mae:8.11148
# [1928]	train-mae:11.74080	eval-mae:8.11127
# [1929]	train-mae:11.73995	eval-mae:8.11080
# [1930]	train-mae:11.73834	eval-mae:8.11054
# [1931]	train-mae:11.73682	eval-mae:8.11051
# [1932]	train-mae:11.73552	eval-mae:8.11073
# [1933]	train-mae:11.73465	eval-mae:8.11047
# [1934]	train-mae:11.73334	eval-mae:8.11040
# [1935]	train-mae:11.73223	eval-mae:8.11036
# [1936]	train-mae:11.73133	eval-mae:8.11012
# [1937]	train-mae:11.73046	eval-mae:8.11012
# [1938]	train-mae:11.72928	eval-mae:8.10897
# [1939]	train-mae:11.72820	eval-mae:8.10897
# [1940]	train-mae:11.72664	eval-mae:8.10897
# [1941]	train-mae:11.72589	eval-mae:8.10872
# [1942]	train-mae:11.72489	eval-mae:8.10842
# [1943]	train-mae:11.72368	eval-mae:8.10838
# [1944]	train-mae:11.72282	eval-mae:8.10841
# [1945]	train-mae:11.72167	eval-mae:8.10829
# [1946]	train-mae:11.72097	eval-mae:8.10796
# [1947]	train-mae:11.72011	eval-mae:8.10773
# [1948]	train-mae:11.71943	eval-mae:8.10762
# [1949]	train-mae:11.71807	eval-mae:8.10754
# [1950]	train-mae:11.71730	eval-mae:8.10755
# [1951]	train-mae:11.71607	eval-mae:8.10755
# [1952]	train-mae:11.71493	eval-mae:8.10756
# [1953]	train-mae:11.71397	eval-mae:8.10716
# [1954]	train-mae:11.71292	eval-mae:8.10691
# [1955]	train-mae:11.71209	eval-mae:8.10682
# [1956]	train-mae:11.71066	eval-mae:8.10682
# [1957]	train-mae:11.70987	eval-mae:8.10681
# [1958]	train-mae:11.70917	eval-mae:8.10671
# [1959]	train-mae:11.70809	eval-mae:8.10673
# [1960]	train-mae:11.70706	eval-mae:8.10660
# [1961]	train-mae:11.70598	eval-mae:8.10668
# [1962]	train-mae:11.70467	eval-mae:8.10624
# [1963]	train-mae:11.70313	eval-mae:8.10405
# [1964]	train-mae:11.70198	eval-mae:8.10405
# [1965]	train-mae:11.70083	eval-mae:8.10405
# [1966]	train-mae:11.69983	eval-mae:8.10413
# [1967]	train-mae:11.69822	eval-mae:8.10416
# [1968]	train-mae:11.69719	eval-mae:8.10417
# [1969]	train-mae:11.69635	eval-mae:8.10418
# [1970]	train-mae:11.69548	eval-mae:8.10418
# [1971]	train-mae:11.69432	eval-mae:8.10418
# [1972]	train-mae:11.69357	eval-mae:8.10414
# [1973]	train-mae:11.69256	eval-mae:8.10406
# [1974]	train-mae:11.69087	eval-mae:8.10406
# [1975]	train-mae:11.68972	eval-mae:8.10393
# [1976]	train-mae:11.68865	eval-mae:8.10377
# [1977]	train-mae:11.68767	eval-mae:8.10375
# [1978]	train-mae:11.68677	eval-mae:8.10373
# [1979]	train-mae:11.68586	eval-mae:8.10362
# [1980]	train-mae:11.68505	eval-mae:8.10361
# [1981]	train-mae:11.68398	eval-mae:8.10351
# [1982]	train-mae:11.68301	eval-mae:8.10350
# [1983]	train-mae:11.68223	eval-mae:8.10355
# [1984]	train-mae:11.68106	eval-mae:8.10295
# [1985]	train-mae:11.68018	eval-mae:8.10261
# [1986]	train-mae:11.67906	eval-mae:8.10264
# [1987]	train-mae:11.67790	eval-mae:8.10254
# [1988]	train-mae:11.67703	eval-mae:8.10256
# [1989]	train-mae:11.67616	eval-mae:8.10202
# [1990]	train-mae:11.67512	eval-mae:8.10166
# [1991]	train-mae:11.67418	eval-mae:8.10137
# [1992]	train-mae:11.67290	eval-mae:8.10135
# [1993]	train-mae:11.67194	eval-mae:8.10134
# [1994]	train-mae:11.67086	eval-mae:8.10132
# [1995]	train-mae:11.66961	eval-mae:8.10133
# [1996]	train-mae:11.66870	eval-mae:8.10149
# [1997]	train-mae:11.66770	eval-mae:8.10145
# [1998]	train-mae:11.66690	eval-mae:8.10132
# [1999]	train-mae:11.66622	eval-mae:8.10132

# %% [markdown]
# # Compare

# %%
mae_xgb = mean_absolute_error(y_test, predictions_xgb)
print(f"XGBoost  MAE: {mae_xgb:.4f}")
# Out:
# XGBoost  MAE: 8.1013

# %% [markdown]
# # Visualization

# %%
# 1. Create a DataFrame for XGBoost results
# Ensure 'predictions_xgb' is the output from bst.predict(dtest)
results_xgb = pd.DataFrame({
    'Actual': y_test,
    'XGBoost_Forecast': predictions_xgb
}, index=y_test.index)

# 2. Plotting the 28-day window (2688 rows)
plt.figure(figsize=(15, 7))

# Plot Actual Data
plt.plot(results_xgb['Actual'].iloc[:2688], 
         label='Ground Truth (Actual)', 
         color='blue', 
         alpha=0.6)

# Plot XGBoost Forecast
plt.plot(results_xgb['XGBoost_Forecast'].iloc[:2688], 
         label='XGBoost Forecast', 
         color='green',           # Using Green to distinguish from LightGBM's Red
         linestyle='--', 
         linewidth=1.5)

plt.title('Conductivity Forecast vs Ground Truth (XGBoost - Sept 2025)')
plt.xlabel('Date')
plt.ylabel('Conductivity (μS/cm)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # Head to head comparison of forecasts

# %%
# Head to head comparison
comparison = pd.DataFrame({
    'Actual':   y_test.values[:2688],
    'LightGBM': forecast[:2688],
    'XGBoost':  predictions_xgb[:2688]
}, index=y_test.index[:2688])

plt.figure(figsize=(15, 8))
plt.plot(comparison['Actual'],   label='Actual',    color='black', alpha=0.4, linewidth=2)
plt.plot(comparison['LightGBM'], label='LightGBM',  color='red',   linestyle=':',  alpha=0.8)
plt.plot(comparison['XGBoost'],  label='XGBoost',   color='green', linestyle='--', alpha=0.8)

plt.title('Comparison: LightGBM vs XGBoost vs Ground Truth')
plt.xlabel('Date')
plt.ylabel('Conductivity (μS/cm)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Ensemble

# %%
final_ensemble = (forecast + predictions_xgb) / 2

mae_ensemble = mean_absolute_error(y_test, final_ensemble)
print(f"Final Ensemble MAE: {mae_ensemble:.4f}")
# Out:
# Final Ensemble MAE: 5.3988

# %%
results = pd.DataFrame({
    'Actual':   y_test.values[:2688],
    'Forecast': forecast[:2688]
}, index=y_test.index[:2688])

plt.figure(figsize=(15, 7))
plt.plot(results['Actual'],   label='Ground Truth (Actual)', color='blue', alpha=0.7)
plt.plot(results['Forecast'], label='LightGBM Forecast',     color='red',  linestyle='--')

plt.title('Conductivity Forecast vs Ground Truth (LightGBM - July 2025)')
plt.xlabel('Date')
plt.ylabel('Conductivity (μS/cm)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
